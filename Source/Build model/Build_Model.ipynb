# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install emoji
import emoji
import pandas as pd
from pyspark.ml import Pipeline
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql import functions as f
from IPython.display import display, clear_output
import pandas as pd
from pyspark.ml import PipelineModel
from pyspark.sql.functions import udf
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
# Out:
# Collecting emoji
#   Downloading emoji-1.4.1.tar.gz (185 kB)
#      |████████████████████████████████| 185 kB 8.2 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.1-py3-none-any.whl size=186393 sha256=7480978061065a0dd4fcffe28dece5660f5459c48292b8a257c9cd5241e82852
#   Stored in directory: /root/.cache/pip/wheels/8e/68/ac/537456a5331f1405779f2b3c2a578429d2f6d7419e440330d8
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.4.1

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
from pyspark.ml.feature import StopWordsRemover
from pyspark.ml.feature import HashingTF, IDF
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression, NaiveBayes
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from sklearn.metrics import classification_report, accuracy_score

# %%
import sparknlp
spark = sparknlp.start(gpu=True)

# %% [markdown]
# # **Read Dataset**

# %%
schema = "text STRING, sentiment FLOAT"
train = spark.read.csv('/content/train_vaccine_tweet.csv', header=True, schema = schema)
test = spark.read.csv('/content/test_vaccine_tweet.csv', header=True, schema = schema)

# %%
train.show(truncate=100)
test.show(truncate=100)
# Out:
# +----------------------------------------------------------------------------------------------------+---------+
# |                                                                                                text|sentiment|
# +----------------------------------------------------------------------------------------------------+---------+
# |@latingle Too bad they didn't order #Moderna or #JohnsonAndJohnsonVaccine  FFS! Incompetent noobs...|      0.0|
# |Yes @DollyParton ❤️❤️❤️❤️🥰🥰🥰. AND THANK YOU! #Moderna   Dolly Parton, 75, receives Moderna COV...|      2.0|
# | I wish anyone taking the mRNA vaccines good luck  You’ll dearly need it  #vaccine #Pfizer #Moderna |      2.0|
# |@BBCWorld New crime against humanity :Israeli occupation banned the entry of 2000 shots of #Sputn...|      0.0|
# |                                                                      @BDUTT #Covaxin airlifted?!? ?|      1.0|
# |UPDATE | Brazil grateful to Russia for allowing Anvisa to inspect #SputnikV production, ambassado...|      1.0|
# |Deputy PM #Golikova: 5 mln Russians have received the first component of ??#vaccine against #covi...|      1.0|
# |Systemic #Reactions Reported within 7 Days after Injection (Dose 2) of #BNT162b2  Data from: http...|      1.0|
# |@Jessicam6946 I can't wait to get my second and have no problem if I do get sick for a day.??????...|      2.0|
# |?  ?  ??  5 more countries suspend use of #Vaccine .. good  luck with getting us all indoctrinate...|      0.0|
# |?? From today, people over 65 years of age is allowed to register for the Covid-19 vaccination in...|      1.0|
# |Not half Vaxed anymore ! I feel like 💩 but it was expected because 4 weeks ago my body was at wa...|      0.0|
# |                                                 I feel so miserable right now! #moderna u a bitch! |      0.0|
# |                                  Ive been lying in bed all day #Moderna #LA https://t.co/6tuNHw3EJO|      0.0|
# |This is very strange, despite WHO approval, Saudi Arabia is still denying to recognize Chinese #S...|      0.0|
# |    Support the little chef🍽️ 🧒💜🙏💙  Please help me getting 2k subscribers 🙏💙🧒💜    #SputnikV|      2.0|
# |??@moderna_tx has begun testing its COVID-19 #vaccine in #children ages 6 months to less than 12 ...|      1.0|
# |#ITAAP has organized #VaccinationDrive across #AP and enabled the vaccination for more than 15,00...|      1.0|
# |#CHCNewsflash: #Probi and @SinopharmIntl #Sinopharm have entered into a partnership to expand pre...|      1.0|
# |                   #Spain to receive fewer #Moderna shots, more from #Pfizer https://t.co/JPzFnG5N1P|      1.0|
# +----------------------------------------------------------------------------------------------------+---------+
# only showing top 20 rows
#
# +----------------------------------------------------------------------------------------------------+---------+
# |                                                                                                text|sentiment|
# +----------------------------------------------------------------------------------------------------+---------+
# |#PfizerBioNTech #Tozinameran has 54,828 reported adverse reactions, and at least 257 deaths (unde...|      0.0|
# |Mom is doing panic buying whereas Dad panic selling #dad #CoronavirusIndia #Covaxin #CoronavirusP...|      0.0|
# |Today is my birthday. For my gift my sons, mother and I were able to get our first dose. #Moderna...|      1.0|
# |                                  #OMI Hospital Karachi is charging Rs 15000/-for #SputnikV vaccine.|      1.0|
# |Our beloved PM, Shri.Narendra Modi takes his 1st Covid shot,Covaxin today 👌💉   #Covaxin #Covish...|      2.0|
# |Super happy to get the #Moderna vaccine 💉 no side effects whatsoever, dose #1 🏆 thank you @Unit...|      2.0|
# |#Covaxin’s Phase 3 trials results likely next month Read More............ #COVID19India #COVID19V...|      1.0|
# |[05:00:27] 400101, 26-06-2021, 19 dose2 at Terapanth Bhavan Ward 24, #COVAXIN Terapanth Bhavan  T...|      1.0|
# |We call on USG to act with speed to trf vaccine tech for global scale up- #Moderna  @PrEP4AllNow ...|      1.0|
# |@BonnieTowner Full vaccinated with #Moderna First shot no sides. Second, arm a bit sore at inject...|      0.0|
# |This laughing at how perfect this tweet is... @2000AD #moderna #modernablock https://t.co/3ChEIPebDT|      1.0|
# |                           I got #Vaccinated #Sinovac #1stDose #Frontliner #Nurse #COVIDVaccination |      1.0|
# |     560078,  AGE 18+ 78-D1, 18-D2 slots, #COVAXIN on 17-06-2021 @ Gvg Invivo Hospital(1410Rs) #BBMP|      1.0|
# | @AshleyM14890553 This is bad news. The first shot was bad enough. My arm hurt for ten days #Moderna|      0.0|
# |@AlexBerenson @AstraZeneca Yep! Just guess who has bribed our governments more! #Pfizer? #Moderna...|      0.0|
# |With approval to 3rd vaccine (#SputnikV) &amp; its roll out expected in a few weeks, India's #Vac...|      1.0|
# |#Delhi: Prime Minister #NarendraModi takes his second dose of #COVID19 vaccine at #AIIMS  He rece...|      1.0|
# |🇨🇳✈️🇹🇩#Chad is the latest African country that receives China-donated #Sinopharm COVID19 vacc...|      1.0|
# |@emirates Group rolls out COVID-19 Vaccination Programme https://t.co/eFggkc1UPY Via: @TheDailyNe...|      2.0|
# |#Russia’s #SputnikV #vaccine to be produced by #Malaysia? #COVID19 #TechnologySharing #Gamaleya #...|      1.0|
# +----------------------------------------------------------------------------------------------------+---------+
# only showing top 20 rows

# %%
train.printSchema()
train.groupBy("sentiment").agg(f.count("sentiment")).show()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#
# +---------+----------------+
# |sentiment|count(sentiment)|
# +---------+----------------+
# |      2.0|            3150|
# |      1.0|            4320|
# |      0.0|            1530|
# +---------+----------------+

# %%
test.printSchema()
test.groupBy("sentiment").agg(f.count("sentiment")).show()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#
# +---------+----------------+
# |sentiment|count(sentiment)|
# +---------+----------------+
# |      2.0|             350|
# |      1.0|             480|
# |      0.0|             170|
# +---------+----------------+

# %% [markdown]
# # **Preprocessing Text**

# %%
def emoji2text(text):
    return emoji.demojize(text, delimiters=(" ", " "))

udf_emoji2text = udf(emoji2text,StringType())

# %%
user_regex = r"(@\w{1,15})"
hashtag_replace_regex = "#(\w{1,})"
url_regex = r"(https?:\/\/\S+|www\.\S+)"
email_regex = r"[\w.-]+@[\w.-]+.[a-zA-Z]{1,}"
RT_regex = r"RT"

def cleaning_process(data):
            # Loại bỏ @Mention khỏi text
    data=(data.withColumn("text",f.regexp_replace(f.col("text"), user_regex, "")) 
            # Loại bỏ dấu # khỏi Hashtag khỏi text
            .withColumn("text",f.regexp_replace(f.col("text"), hashtag_replace_regex, "$1"))
            # Loại bỏ URL khỏi text
            .withColumn("text",f.regexp_replace(f.col("text"), url_regex, "")) 
            # Loại bỏ Email khỏi text
            .withColumn("text",f.regexp_replace(f.col("text"), email_regex, ""))
            # Loại bỏ RT khỏi text
            .withColumn("text",f.regexp_replace(f.col("text"), RT_regex, ""))
            # Emoji 2 text
            .withColumn('text', udf_emoji2text(f.col('text')))
            # Loại bỏ số cũng như các ký tự khỏi đoạn text
            .withColumn("text",f.regexp_replace(f.col("text"), "[^a-zA-Z]", " "))
            # Loại bỏ các khoảng trắng thừa trong câu
            .withColumn("text",f.regexp_replace(f.col("text"), " +", " "))
            # Loại vỏ các khoảng trắng đầu và cuối câu
            .withColumn("text",f.trim(f.col("text")))
            # Chuẩn hoá viết thường
            .withColumn("text",f.lower(f.col("text")))
            # Giữ lại các dòng mà đoạn text có nội dung 
            .filter(f.col("text") != ""))
    return data

# %%
train = cleaning_process(train)
test = cleaning_process(test)

# %%
# Show Cleaned Text
train.show(truncate=100)
test.show(truncate=100)
# Out:
# +----------------------------------------------------------------------------------------------------+---------+
# |                                                                                                text|sentiment|
# +----------------------------------------------------------------------------------------------------+---------+
# |   too bad they didn t order moderna or johnsonandjohnsonvaccine ffs incompetent noobs this means my|      0.0|
# |yes red heart red heart red heart red heart smiling face with hearts smiling face with hearts smi...|      2.0|
# |       i wish anyone taking the mrna vaccines good luck you ll dearly need it vaccine pfizer moderna|      2.0|
# |      new crime against humanity israeli occupation banned the entry of shots of sputnikv vaccine to|      0.0|
# |                                                                                   covaxin airlifted|      1.0|
# |update brazil grateful to russia for allowing anvisa to inspect sputnikv production ambassador sa...|      1.0|
# |deputy pm golikova mln russians have received the first component of vaccine against covid while ...|      1.0|
# |systemic reactions reported within days after injection dose of bnt b data from pfizerbiontech va...|      1.0|
# |        i can t wait to get my second and have no problem if i do get sick for a day worthit moderna|      2.0|
# |more countries suspend use of vaccine good luck with getting us all indoctrinated with your evil ...|      0.0|
# |from today people over years of age is allowed to register for the covid vaccination in the count...|      1.0|
# |not half vaxed anymore i feel like pile of poo but it was expected because weeks ago my body was ...|      0.0|
# |                                                     i feel so miserable right now moderna u a bitch|      0.0|
# |                                                            ive been lying in bed all day moderna la|      0.0|
# |this is very strange despite who approval saudi arabia is still denying to recognize chinese sino...|      0.0|
# |support the little chef fork and knife with plate child purple heart folded hands blue heart plea...|      2.0|
# |has begun testing its covid vaccine in children ages months to less than years this is the first ...|      1.0|
# |itaap has organized vaccinationdrive across ap and enabled the vaccination for more than itemploy...|      1.0|
# |chcnewsflash probi and sinopharm have entered into a partnership to expand premium probiotic offe...|      1.0|
# |                                               spain to receive fewer moderna shots more from pfizer|      1.0|
# +----------------------------------------------------------------------------------------------------+---------+
# only showing top 20 rows
#
# +----------------------------------------------------------------------------------------------------+---------+
# |                                                                                                text|sentiment|
# +----------------------------------------------------------------------------------------------------+---------+
# |  pfizerbiontech tozinameran has reported adverse reactions and at least deaths under death category|      0.0|
# |mom is doing panic buying whereas dad panic selling dad coronavirusindia covaxin coronaviruspandemic|      0.0|
# |today is my birthday for my gift my sons mother and i were able to get our first dose moderna vac...|      1.0|
# |                                            omi hospital karachi is charging rs for sputnikv vaccine|      1.0|
# |our beloved pm shri narendra modi takes his st covid shot covaxin today ok hand syringe covaxin c...|      2.0|
# |     super happy to get the moderna vaccine syringe no side effects whatsoever dose trophy thank you|      2.0|
# |                covaxin s phase trials results likely next month read more covid india covid vaccine|      1.0|
# |                          dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand|      1.0|
# |                    we call on usg to act with speed to trf vaccine tech for global scale up moderna|      1.0|
# |    full vaccinated with moderna first shot no sides second arm a bit sore at injection site tired r|      0.0|
# |                                     this laughing at how perfect this tweet is moderna modernablock|      1.0|
# |                                   i got vaccinated sinovac stdose frontliner nurse covidvaccination|      1.0|
# |                                                age d d slots covaxin on gvg invivo hospital rs bbmp|      1.0|
# |                     this is bad news the first shot was bad enough my arm hurt for ten days moderna|      0.0|
# |yep just guess who has bribed our governments more pfizer moderna astrazeneca it s all a sham no ...|      0.0|
# |with approval to rd vaccine sputnikv amp its roll out expected in a few weeks india s vaccination...|      1.0|
# |delhi prime minister narendramodi takes his second dose of covid vaccine at aiims he received the...|      1.0|
# |china airplane chad chad is the latest african country that receives china donated sinopharm covi...|      1.0|
# |group rolls out covid vaccination programme via vaccination covidvaccine frontlineworkers frontli...|      2.0|
# |  russia s sputnikv vaccine to be produced by malaysia covid technologysharing gamaleya vaccinedeals|      1.0|
# +----------------------------------------------------------------------------------------------------+---------+
# only showing top 20 rows

# %% [markdown]
# # **TF-IDF + Naive Bayes (✔️)**

# %%
# Define Spark NLP pipleline
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

sentence = SentenceDetector() \
          .setInputCols(['document']) \
          .setOutputCol('sentences')

token = Tokenizer() \
        .setInputCols(["sentences"]) \
        .setOutputCol("token")

#stop_words = StopWordsCleaner.pretrained('stopwords_en', 'en').setInputCols(["token"]).setOutputCol("cleanTokens").setCaseSensitive(False)

lemmatizer = LemmatizerModel.pretrained("lemma_antbnc", "en") \
            .setInputCols(["token"]) \
            .setOutputCol("lemma")

finisher = Finisher().setInputCols(["lemma"]).setOutputCols("token_features").setOutputAsArray(True).setCleanAnnotations(False)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]

# %%
hashtf = HashingTF(inputCol="token_features", outputCol="raw_features")

idf = IDF(inputCol='raw_features', outputCol="features", minDocFreq=5) 

nv = NaiveBayes(labelCol="sentiment", featuresCol="features", smoothing=111)

nlp_pipeline_nv = Pipeline(stages=[document, 
                                   sentence, 
                                   token, 
                                   #stop_words, 
                                   lemmatizer, 
                                   finisher, 
                                   hashtf, 
                                   idf, 
                                   nv])

# %%
model_nv = nlp_pipeline_nv.fit(train)
predict_train = model_nv.transform(train)
predict_test = model_nv.transform(test)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       1.00      0.03      0.06       170
#      Neutral       0.60      0.92      0.72       480
#     Positive       0.80      0.58      0.67       350
#
#     accuracy                           0.65      1000
#    macro avg       0.80      0.51      0.48      1000
# weighted avg       0.74      0.65      0.59      1000

# %% [markdown]
# # **TF-IDF + Logistic Regression (✔️)**

# %%
hashtf = HashingTF(inputCol="token_features", outputCol="raw_features")

idf = IDF(inputCol='raw_features', outputCol="features", minDocFreq=5) 

lr = LogisticRegression(maxIter=10, regParam = 0.01, featuresCol="features", labelCol="sentiment")

nlp_pipeline_lr = Pipeline(stages=[document, 
                                   sentence, 
                                   token, 
                                   #stop_words, 
                                   lemmatizer, 
                                   finisher, 
                                   hashtf, 
                                   idf, 
                                   lr])

# %%
model_lr = nlp_pipeline_lr.fit(train)
predict_train = model_lr.transform(train)
predict_test = model_lr.transform(test)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.76      0.62      0.68       170
#      Neutral       0.74      0.76      0.75       480
#     Positive       0.71      0.75      0.73       350
#
#     accuracy                           0.73      1000
#    macro avg       0.74      0.71      0.72      1000
# weighted avg       0.73      0.73      0.73      1000

# %% [markdown]
# # **Bert base uncased and ClassifierDLApproach**

# %%
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

embeddings = BertSentenceEmbeddings.pretrained("sent_bert_base_uncased", "en") \
            .setInputCols(["document"]) \
            .setOutputCol("sentence_embeddings")

classifierdl = ClassifierDLApproach() \
              .setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction") \
              .setLabelColumn("sentiment") \
              .setMaxEpochs(10) \
              .setBatchSize(32) \
              .setEnableOutputLogs(True)
# Out:
# sent_bert_base_uncased download started this may take some time.
# Approximate size to download 392.5 MB
# [OK!]

# %%
nlp_pipeline_BERT = Pipeline(stages=[document, 
                                     embeddings, 
                                     classifierdl])

# %%
model_BERT_labse = nlp_pipeline_BERT.fit(train)

predict_test = model_BERT_labse.transform(test)

# %%
predict_test.show()
# Out:
# +--------------------+---------+--------------------+--------------------+--------------------+
# |                text|sentiment|            document| sentence_embeddings|          prediction|
# +--------------------+---------+--------------------+--------------------+--------------------+
# |pfizerbiontech to...|      0.0|[{document, 0, 97...|[{sentence_embedd...|[{category, 0, 97...|
# |mom is doing pani...|      0.0|[{document, 0, 99...|[{sentence_embedd...|[{category, 0, 99...|
# |today is my birth...|      1.0|[{document, 0, 14...|[{sentence_embedd...|[{category, 0, 14...|
# |omi hospital kara...|      1.0|[{document, 0, 55...|[{sentence_embedd...|[{category, 0, 55...|
# |our beloved pm sh...|      2.0|[{document, 0, 11...|[{sentence_embedd...|[{category, 0, 11...|
# |super happy to ge...|      2.0|[{document, 0, 94...|[{sentence_embedd...|[{category, 0, 94...|
# |covaxin s phase t...|      1.0|[{document, 0, 83...|[{sentence_embedd...|[{category, 0, 83...|
# |dose at terapanth...|      1.0|[{document, 0, 73...|[{sentence_embedd...|[{category, 0, 73...|
# |we call on usg to...|      1.0|[{document, 0, 79...|[{sentence_embedd...|[{category, 0, 79...|
# |full vaccinated w...|      0.0|[{document, 0, 95...|[{sentence_embedd...|[{category, 0, 95...|
# |this laughing at ...|      1.0|[{document, 0, 62...|[{sentence_embedd...|[{category, 0, 62...|
# |i got vaccinated ...|      1.0|[{document, 0, 64...|[{sentence_embedd...|[{category, 0, 64...|
# |age d d slots cov...|      1.0|[{document, 0, 51...|[{sentence_embedd...|[{category, 0, 51...|
# |this is bad news ...|      0.0|[{document, 0, 78...|[{sentence_embedd...|[{category, 0, 78...|
# |yep just guess wh...|      0.0|[{document, 0, 24...|[{sentence_embedd...|[{category, 0, 24...|
# |with approval to ...|      1.0|[{document, 0, 24...|[{sentence_embedd...|[{category, 0, 24...|
# |delhi prime minis...|      1.0|[{document, 0, 19...|[{sentence_embedd...|[{category, 0, 19...|
# |china airplane ch...|      1.0|[{document, 0, 12...|[{sentence_embedd...|[{category, 0, 12...|
# |group rolls out c...|      2.0|[{document, 0, 13...|[{sentence_embedd...|[{category, 0, 13...|
# |russia s sputnikv...|      1.0|[{document, 0, 97...|[{sentence_embedd...|[{category, 0, 97...|
# +--------------------+---------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- prediction: double (nullable = true)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00       170
#      Neutral       0.00      0.00      0.00       480
#     Positive       0.35      1.00      0.52       350
#
#     accuracy                           0.35      1000
#    macro avg       0.12      0.33      0.17      1000
# weighted avg       0.12      0.35      0.18      1000
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# - epoch = 1: 0.12, 0.33, 0.17
# - epoch = 5: 0.12, 0.33, 0.17
# - epoch = 10, batchsize = 32: 0.12, 0.33, 0.17

# %% [markdown]
# # **Universal Sentence Encoder and ClassifierDLApproach (✔️)**
# https://nlp.johnsnowlabs.com/2020/04/17/tfhub_use.html

# %%
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

embeddings = UniversalSentenceEncoder.pretrained("tfhub_use", "en") \
            .setInputCols(["document"]) \
            .setOutputCol("sentence_embeddings")

classifierdl = ClassifierDLApproach() \
              .setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction") \
              .setLabelColumn("sentiment") \
              .setBatchSize(64) \
              .setMaxEpochs(10) \
              .setLr(0.005) \
              .setEnableOutputLogs(True)
# Out:
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]

# %%
nlp_pipeline_USE = Pipeline(stages=[document, 
                                   embeddings, 
                                   classifierdl])

# %%
model_USE = nlp_pipeline_USE.fit(train)

predict_test = model_USE.transform(test)

# %%
predict_test.show(truncate=100)
#predict_test.select("sentence_embeddings").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |                                                                                                text|sentiment|                                                                                            document|                                                                                 sentence_embeddings|                                                                                          prediction|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |  pfizerbiontech tozinameran has reported adverse reactions and at least deaths under death category|      0.0|[[document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[[sentence_embeddings, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at le...|[[category, 0, 97, 0.0, [sentence -> 0, 1.0 -> 5.921601E-6, 0.0 -> 0.9999939, 2.0 -> 1.5407878E-7...|
# |mom is doing panic buying whereas dad panic selling dad coronavirusindia covaxin coronaviruspandemic|      0.0|[[document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[[sentence_embeddings, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirus...|[[category, 0, 99, 0.0, [sentence -> 0, 1.0 -> 3.2205737E-4, 0.0 -> 0.99967015, 2.0 -> 7.790158E-...|
# |today is my birthday for my gift my sons mother and i were able to get our first dose moderna vac...|      1.0|[[document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[[sentence_embeddings, 0, 146, today is my birthday for my gift my sons mother and i were able to...|[[category, 0, 146, 2.0, [sentence -> 0, 1.0 -> 1.3558106E-5, 0.0 -> 3.3352285E-9, 2.0 -> 0.99998...|
# |                                            omi hospital karachi is charging rs for sputnikv vaccine|      1.0|  [[document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, [sentence -> 0], []]]|[[sentence_embeddings, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, [sentence...|[[category, 0, 55, 1.0, [sentence -> 0, 1.0 -> 0.9999927, 0.0 -> 1.2489612E-6, 2.0 -> 6.0330053E-...|
# |our beloved pm shri narendra modi takes his st covid shot covaxin today ok hand syringe covaxin c...|      2.0|[[document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[[sentence_embeddings, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin ...|[[category, 0, 117, 1.0, [sentence -> 0, 1.0 -> 0.99906474, 0.0 -> 4.0104546E-9, 2.0 -> 9.3527493...|
# |     super happy to get the moderna vaccine syringe no side effects whatsoever dose trophy thank you|      2.0|[[document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[[sentence_embeddings, 0, 94, super happy to get the moderna vaccine syringe no side effects what...|[[category, 0, 94, 2.0, [sentence -> 0, 1.0 -> 1.4823638E-6, 0.0 -> 4.695933E-10, 2.0 -> 0.999998...|
# |                covaxin s phase trials results likely next month read more covid india covid vaccine|      1.0|[[document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[[sentence_embeddings, 0, 83, covaxin s phase trials results likely next month read more covid in...|[[category, 0, 83, 1.0, [sentence -> 0, 1.0 -> 0.9963703, 0.0 -> 3.5193935E-7, 2.0 -> 0.003629359...|
# |                          dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand|      1.0|[[document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, [s...|[[sentence_embeddings, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur compl...| [[category, 0, 73, 1.0, [sentence -> 0, 1.0 -> 1.0, 0.0 -> 7.620834E-11, 2.0 -> 1.2913713E-8], []]]|
# |                    we call on usg to act with speed to trf vaccine tech for global scale up moderna|      1.0|[[document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[[sentence_embeddings, 0, 79, we call on usg to act with speed to trf vaccine tech for global sca...|[[category, 0, 79, 1.0, [sentence -> 0, 1.0 -> 0.9987896, 0.0 -> 1.5390677E-8, 2.0 -> 0.001210363...|
# |    full vaccinated with moderna first shot no sides second arm a bit sore at injection site tired r|      0.0|[[document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[[sentence_embeddings, 0, 95, full vaccinated with moderna first shot no sides second arm a bit s...|[[category, 0, 95, 1.0, [sentence -> 0, 1.0 -> 0.9953524, 0.0 -> 0.0016666446, 2.0 -> 0.002980981...|
# |                                     this laughing at how perfect this tweet is moderna modernablock|      1.0|[[document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, [sentence -> ...|[[sentence_embeddings, 0, 62, this laughing at how perfect this tweet is moderna modernablock, [s...|[[category, 0, 62, 2.0, [sentence -> 0, 1.0 -> 0.10828093, 0.0 -> 8.043082E-6, 2.0 -> 0.891711], ...|
# |                                   i got vaccinated sinovac stdose frontliner nurse covidvaccination|      1.0|[[document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, [sentence -...|[[sentence_embeddings, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, ...|[[category, 0, 64, 1.0, [sentence -> 0, 1.0 -> 0.9420817, 0.0 -> 9.0667905E-5, 2.0 -> 0.057827666...|
# |                                                age d d slots covaxin on gvg invivo hospital rs bbmp|      1.0|      [[document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, [sentence -> 0], []]]|[[sentence_embeddings, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, [sentence -> ...|[[category, 0, 51, 1.0, [sentence -> 0, 1.0 -> 1.0, 0.0 -> 1.8515048E-12, 2.0 -> 5.801831E-10], []]]|
# |                     this is bad news the first shot was bad enough my arm hurt for ten days moderna|      0.0|[[document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[[sentence_embeddings, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten ...|[[category, 0, 78, 0.0, [sentence -> 0, 1.0 -> 4.5972603E-5, 0.0 -> 0.99995136, 2.0 -> 2.606374E-...|
# |yep just guess who has bribed our governments more pfizer moderna astrazeneca it s all a sham no ...|      0.0|[[document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[[sentence_embeddings, 0, 242, yep just guess who has bribed our governments more pfizer moderna ...|[[category, 0, 242, 2.0, [sentence -> 0, 1.0 -> 0.006074978, 0.0 -> 2.0647085E-5, 2.0 -> 0.993904...|
# |with approval to rd vaccine sputnikv amp its roll out expected in a few weeks india s vaccination...|      1.0|[[document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[[sentence_embeddings, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in ...|[[category, 0, 241, 1.0, [sentence -> 0, 1.0 -> 0.992174, 0.0 -> 1.6631455E-7, 2.0 -> 0.007825815...|
# |delhi prime minister narendramodi takes his second dose of covid vaccine at aiims he received the...|      1.0|[[document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[[sentence_embeddings, 0, 193, delhi prime minister narendramodi takes his second dose of covid v...|[[category, 0, 193, 1.0, [sentence -> 0, 1.0 -> 0.9999989, 0.0 -> 1.0040844E-9, 2.0 -> 1.1251021E...|
# |china airplane chad chad is the latest african country that receives china donated sinopharm covi...|      1.0|[[document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[[sentence_embeddings, 0, 122, china airplane chad chad is the latest african country that receiv...|[[category, 0, 122, 1.0, [sentence -> 0, 1.0 -> 0.99947304, 0.0 -> 4.0802572E-4, 2.0 -> 1.1887023...|
# |group rolls out covid vaccination programme via vaccination covidvaccine frontlineworkers frontli...|      2.0|[[document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[[sentence_embeddings, 0, 136, group rolls out covid vaccination programme via vaccination covidv...|[[category, 0, 136, 1.0, [sentence -> 0, 1.0 -> 0.98475605, 0.0 -> 1.5409522E-7, 2.0 -> 0.0152438...|
# |  russia s sputnikv vaccine to be produced by malaysia covid technologysharing gamaleya vaccinedeals|      1.0|[[document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[[sentence_embeddings, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technolo...|[[category, 0, 97, 1.0, [sentence -> 0, 1.0 -> 0.9997894, 0.0 -> 1.4792669E-5, 2.0 -> 1.9577314E-...|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- prediction: double (nullable = true)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.72      0.59      0.65       170
#      Neutral       0.72      0.82      0.77       480
#     Positive       0.77      0.70      0.73       350
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.70      0.72      1000
# weighted avg       0.74      0.74      0.74      1000

# %% [markdown]
# - epoch = 1: 68, 64, 65
# - epoch = 5: 72, 71, 71
# - epoch = 10: 74, 70, 72

# %% [markdown]
# # **GloVe840B and ClassifierDLApproach (✔️)**
# https://nlp.johnsnowlabs.com/2020/01/22/glove_840B_300.html

# %%
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

sentence = SentenceDetector() \
          .setInputCols(['document']) \
          .setOutputCol('sentences')

token = Tokenizer() \
        .setInputCols(["sentences"]) \
        .setOutputCol("token")

#stop_words = StopWordsCleaner.pretrained('stopwords_en', 'en').setInputCols(["token"]).setOutputCol("cleanTokens").setCaseSensitive(False)

lemmatizer = LemmatizerModel.pretrained("lemma_antbnc", "en") \
            .setInputCols(["token"]) \
            .setOutputCol("lemma")

glove_embeddings = WordEmbeddingsModel().pretrained('glove_840B_300','xx') \
                  .setInputCols(["sentences","lemma"]) \
                  .setOutputCol("embeddings") \
                  .setCaseSensitive(False)

embeddingsSentence = SentenceEmbeddings() \
                    .setInputCols(["sentences", "embeddings"]) \
                    .setOutputCol("sentence_embeddings") \
                    .setPoolingStrategy("AVERAGE")

classifierdl = ClassifierDLApproach().setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction") \
              .setLabelColumn("sentiment") \
              .setBatchSize(32) \
              .setMaxEpochs(10) \
              .setLr(0.003) \
              .setEnableOutputLogs(True)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]
# glove_840B_300 download started this may take some time.
# Approximate size to download 2.3 GB
# [OK!]

# %%
nlp_pipeline_glove = Pipeline(stages=[document,
                                      sentence,
                                      token,
                                      lemmatizer, 
                                      glove_embeddings,
                                      embeddingsSentence,
                                      classifierdl])

# %%
model_glove = nlp_pipeline_glove.fit(train)

predict_test = model_glove.transform(test)

# %%
predict_test.show(truncate=100)
#predict_test.select("sentence_embeddings").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |                                                                                                text|sentiment|                                                                                            document|                                                                                           sentences|                                                                                               token|                                                                                               lemma|                                                                                          embeddings|                                                                                 sentence_embeddings|                                                                                          prediction|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |  pfizerbiontech tozinameran has reported adverse reactions and at least deaths under death category|      0.0|[[document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[[document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[[token, 0, 13, pfizerbiontech, [sentence -> 0], []], [token, 15, 25, tozinameran, [sentence -> 0...|[[token, 0, 13, pfizerbiontech, [sentence -> 0], []], [token, 15, 25, tozinameran, [sentence -> 0...|[[word_embeddings, 0, 13, pfizerbiontech, [isOOV -> true, pieceId -> -1, isWordStart -> true, tok...|[[sentence_embeddings, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at le...|[[category, 0, 97, 0.0, [sentence -> 0, 1.0 -> 1.4230108E-4, 0.0 -> 0.9998573, 2.0 -> 3.2515916E-...|
# |mom is doing panic buying whereas dad panic selling dad coronavirusindia covaxin coronaviruspandemic|      0.0|[[document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[[document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[[token, 0, 2, mom, [sentence -> 0], []], [token, 4, 5, is, [sentence -> 0], []], [token, 7, 11, ...|[[token, 0, 2, mom, [sentence -> 0], []], [token, 4, 5, be, [sentence -> 0], []], [token, 7, 11, ...|[[word_embeddings, 0, 2, mom, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> mom, ...|[[sentence_embeddings, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirus...|[[category, 0, 99, 0.0, [sentence -> 0, 1.0 -> 0.0017551124, 0.0 -> 0.9982436, 2.0 -> 1.2515894E-...|
# |today is my birthday for my gift my sons mother and i were able to get our first dose moderna vac...|      1.0|[[document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[[document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[[token, 0, 4, today, [sentence -> 0], []], [token, 6, 7, is, [sentence -> 0], []], [token, 9, 10...|[[token, 0, 4, today, [sentence -> 0], []], [token, 6, 7, be, [sentence -> 0], []], [token, 9, 10...|[[word_embeddings, 0, 4, today, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> tod...|[[sentence_embeddings, 0, 146, today is my birthday for my gift my sons mother and i were able to...|[[category, 0, 146, 2.0, [sentence -> 0, 1.0 -> 0.0014034829, 0.0 -> 1.2252858E-7, 2.0 -> 0.99859...|
# |                                            omi hospital karachi is charging rs for sputnikv vaccine|      1.0|  [[document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, [sentence -> 0], []]]|  [[document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, [sentence -> 0], []]]|[[token, 0, 2, omi, [sentence -> 0], []], [token, 4, 11, hospital, [sentence -> 0], []], [token, ...|[[token, 0, 2, omi, [sentence -> 0], []], [token, 4, 11, hospital, [sentence -> 0], []], [token, ...|[[word_embeddings, 0, 2, omi, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> omi, ...|[[sentence_embeddings, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, [sentence...|[[category, 0, 55, 0.0, [sentence -> 0, 1.0 -> 0.22993161, 0.0 -> 0.77005637, 2.0 -> 1.2030632E-5...|
# |our beloved pm shri narendra modi takes his st covid shot covaxin today ok hand syringe covaxin c...|      2.0|[[document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[[document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[[token, 0, 2, our, [sentence -> 0], []], [token, 4, 10, beloved, [sentence -> 0], []], [token, 1...|[[token, 0, 2, we, [sentence -> 0], []], [token, 4, 10, beloved, [sentence -> 0], []], [token, 12...|[[word_embeddings, 0, 2, we, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> we, se...|[[sentence_embeddings, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin ...|[[category, 0, 117, 1.0, [sentence -> 0, 1.0 -> 0.99957496, 0.0 -> 7.207436E-7, 2.0 -> 4.2428545E...|
# |     super happy to get the moderna vaccine syringe no side effects whatsoever dose trophy thank you|      2.0|[[document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[[document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[[token, 0, 4, super, [sentence -> 0], []], [token, 6, 10, happy, [sentence -> 0], []], [token, 1...|[[token, 0, 4, super, [sentence -> 0], []], [token, 6, 10, happy, [sentence -> 0], []], [token, 1...|[[word_embeddings, 0, 4, super, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> sup...|[[sentence_embeddings, 0, 94, super happy to get the moderna vaccine syringe no side effects what...|[[category, 0, 94, 2.0, [sentence -> 0, 1.0 -> 3.3490019E-6, 0.0 -> 5.6722255E-10, 2.0 -> 0.99999...|
# |                covaxin s phase trials results likely next month read more covid india covid vaccine|      1.0|[[document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[[document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[[token, 0, 6, covaxin, [sentence -> 0], []], [token, 8, 8, s, [sentence -> 0], []], [token, 10, ...|[[token, 0, 6, covaxin, [sentence -> 0], []], [token, 8, 8, s, [sentence -> 0], []], [token, 10, ...|[[word_embeddings, 0, 6, covaxin, [isOOV -> true, pieceId -> -1, isWordStart -> true, token -> co...|[[sentence_embeddings, 0, 83, covaxin s phase trials results likely next month read more covid in...|[[category, 0, 83, 1.0, [sentence -> 0, 1.0 -> 0.9998388, 0.0 -> 1.5648756E-4, 2.0 -> 4.606417E-6...|
# |                          dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand|      1.0|[[document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, [s...|[[document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, [s...|[[token, 0, 3, dose, [sentence -> 0], []], [token, 5, 6, at, [sentence -> 0], []], [token, 8, 16,...|[[token, 0, 3, dose, [sentence -> 0], []], [token, 5, 6, at, [sentence -> 0], []], [token, 8, 16,...|[[word_embeddings, 0, 3, dose, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> dose...|[[sentence_embeddings, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur compl...|  [[category, 0, 73, 1.0, [sentence -> 0, 1.0 -> 1.0, 0.0 -> 1.1029031E-8, 2.0 -> 5.075813E-8], []]]|
# |                    we call on usg to act with speed to trf vaccine tech for global scale up moderna|      1.0|[[document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[[document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[[token, 0, 1, we, [sentence -> 0], []], [token, 3, 6, call, [sentence -> 0], []], [token, 8, 9, ...|[[token, 0, 1, we, [sentence -> 0], []], [token, 3, 6, call, [sentence -> 0], []], [token, 8, 9, ...|[[word_embeddings, 0, 1, we, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> we, se...|[[sentence_embeddings, 0, 79, we call on usg to act with speed to trf vaccine tech for global sca...|[[category, 0, 79, 1.0, [sentence -> 0, 1.0 -> 0.9976985, 0.0 -> 7.5231543E-7, 2.0 -> 0.002300846...|
# |    full vaccinated with moderna first shot no sides second arm a bit sore at injection site tired r|      0.0|[[document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[[document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[[token, 0, 3, full, [sentence -> 0], []], [token, 5, 14, vaccinated, [sentence -> 0], []], [toke...|[[token, 0, 3, full, [sentence -> 0], []], [token, 5, 14, vaccinate, [sentence -> 0], []], [token...|[[word_embeddings, 0, 3, full, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> full...|[[sentence_embeddings, 0, 95, full vaccinated with moderna first shot no sides second arm a bit s...|[[category, 0, 95, 0.0, [sentence -> 0, 1.0 -> 0.010222444, 0.0 -> 0.9878742, 2.0 -> 0.0019032458...|
# |                                     this laughing at how perfect this tweet is moderna modernablock|      1.0|[[document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, [sentence -> ...|[[document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, [sentence -> ...|[[token, 0, 3, this, [sentence -> 0], []], [token, 5, 12, laughing, [sentence -> 0], []], [token,...|[[token, 0, 3, this, [sentence -> 0], []], [token, 5, 12, laugh, [sentence -> 0], []], [token, 14...|[[word_embeddings, 0, 3, this, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> this...|[[sentence_embeddings, 0, 62, this laughing at how perfect this tweet is moderna modernablock, [s...|[[category, 0, 62, 2.0, [sentence -> 0, 1.0 -> 3.890108E-4, 0.0 -> 3.2286177E-8, 2.0 -> 0.9996109...|
# |                                   i got vaccinated sinovac stdose frontliner nurse covidvaccination|      1.0|[[document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, [sentence -...|[[document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, [sentence -...|[[token, 0, 0, i, [sentence -> 0], []], [token, 2, 4, got, [sentence -> 0], []], [token, 6, 15, v...|[[token, 0, 0, i, [sentence -> 0], []], [token, 2, 4, get, [sentence -> 0], []], [token, 6, 15, v...|[[word_embeddings, 0, 0, i, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> i, sent...|[[sentence_embeddings, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, ...|[[category, 0, 64, 1.0, [sentence -> 0, 1.0 -> 0.92827255, 0.0 -> 4.3841693E-4, 2.0 -> 0.07128899...|
# |                                                age d d slots covaxin on gvg invivo hospital rs bbmp|      1.0|      [[document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, [sentence -> 0], []]]|      [[document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, [sentence -> 0], []]]|[[token, 0, 2, age, [sentence -> 0], []], [token, 4, 4, d, [sentence -> 0], []], [token, 6, 6, d,...|[[token, 0, 2, age, [sentence -> 0], []], [token, 4, 4, d, [sentence -> 0], []], [token, 6, 6, d,...|[[word_embeddings, 0, 2, age, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> age, ...|[[sentence_embeddings, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, [sentence -> ...|[[category, 0, 51, 1.0, [sentence -> 0, 1.0 -> 1.0, 0.0 -> 9.4400745E-9, 2.0 -> 2.9630125E-11], []]]|
# |                     this is bad news the first shot was bad enough my arm hurt for ten days moderna|      0.0|[[document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[[document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[[token, 0, 3, this, [sentence -> 0], []], [token, 5, 6, is, [sentence -> 0], []], [token, 8, 10,...|[[token, 0, 3, this, [sentence -> 0], []], [token, 5, 6, be, [sentence -> 0], []], [token, 8, 10,...|[[word_embeddings, 0, 3, this, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> this...|[[sentence_embeddings, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten ...|[[category, 0, 78, 0.0, [sentence -> 0, 1.0 -> 6.318694E-4, 0.0 -> 0.9992204, 2.0 -> 1.476563E-4]...|
# |yep just guess who has bribed our governments more pfizer moderna astrazeneca it s all a sham no ...|      0.0|[[document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[[document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[[token, 0, 2, yep, [sentence -> 0], []], [token, 4, 7, just, [sentence -> 0], []], [token, 9, 13...|[[token, 0, 2, yep, [sentence -> 0], []], [token, 4, 7, just, [sentence -> 0], []], [token, 9, 13...|[[word_embeddings, 0, 2, yep, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> yep, ...|[[sentence_embeddings, 0, 242, yep just guess who has bribed our governments more pfizer moderna ...|[[category, 0, 242, 1.0, [sentence -> 0, 1.0 -> 0.9066655, 0.0 -> 0.07004302, 2.0 -> 0.023291398]...|
# |with approval to rd vaccine sputnikv amp its roll out expected in a few weeks india s vaccination...|      1.0|[[document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[[document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[[token, 0, 3, with, [sentence -> 0], []], [token, 5, 12, approval, [sentence -> 0], []], [token,...|[[token, 0, 3, with, [sentence -> 0], []], [token, 5, 12, approval, [sentence -> 0], []], [token,...|[[word_embeddings, 0, 3, with, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> with...|[[sentence_embeddings, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in ...|[[category, 0, 241, 1.0, [sentence -> 0, 1.0 -> 0.9759486, 0.0 -> 2.1892003E-5, 2.0 -> 0.02402957...|
# |delhi prime minister narendramodi takes his second dose of covid vaccine at aiims he received the...|      1.0|[[document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[[document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[[token, 0, 4, delhi, [sentence -> 0], []], [token, 6, 10, prime, [sentence -> 0], []], [token, 1...|[[token, 0, 4, delhi, [sentence -> 0], []], [token, 6, 10, prime, [sentence -> 0], []], [token, 1...|[[word_embeddings, 0, 4, delhi, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> del...|[[sentence_embeddings, 0, 193, delhi prime minister narendramodi takes his second dose of covid v...|[[category, 0, 193, 1.0, [sentence -> 0, 1.0 -> 0.99999917, 0.0 -> 1.4392687E-7, 2.0 -> 7.048249E...|
# |china airplane chad chad is the latest african country that receives china donated sinopharm covi...|      1.0|[[document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[[document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[[token, 0, 4, china, [sentence -> 0], []], [token, 6, 13, airplane, [sentence -> 0], []], [token...|[[token, 0, 4, china, [sentence -> 0], []], [token, 6, 13, airplane, [sentence -> 0], []], [token...|[[word_embeddings, 0, 4, china, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> chi...|[[sentence_embeddings, 0, 122, china airplane chad chad is the latest african country that receiv...|[[category, 0, 122, 1.0, [sentence -> 0, 1.0 -> 0.99999714, 0.0 -> 1.9514582E-6, 2.0 -> 9.736531E...|
# |group rolls out covid vaccination programme via vaccination covidvaccine frontlineworkers frontli...|      2.0|[[document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[[document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[[token, 0, 4, group, [sentence -> 0], []], [token, 6, 10, rolls, [sentence -> 0], []], [token, 1...|[[token, 0, 4, group, [sentence -> 0], []], [token, 6, 10, roll, [sentence -> 0], []], [token, 12...|[[word_embeddings, 0, 4, group, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> gro...|[[sentence_embeddings, 0, 136, group rolls out covid vaccination programme via vaccination covidv...|[[category, 0, 136, 1.0, [sentence -> 0, 1.0 -> 0.9999958, 0.0 -> 2.1384539E-9, 2.0 -> 4.2108654E...|
# |  russia s sputnikv vaccine to be produced by malaysia covid technologysharing gamaleya vaccinedeals|      1.0|[[document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[[document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[[token, 0, 5, russia, [sentence -> 0], []], [token, 7, 7, s, [sentence -> 0], []], [token, 9, 16...|[[token, 0, 5, russia, [sentence -> 0], []], [token, 7, 7, s, [sentence -> 0], []], [token, 9, 16...|[[word_embeddings, 0, 5, russia, [isOOV -> false, pieceId -> -1, isWordStart -> true, token -> ru...|[[sentence_embeddings, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technolo...|[[category, 0, 97, 1.0, [sentence -> 0, 1.0 -> 0.9998965, 0.0 -> 4.6257122E-5, 2.0 -> 5.7200545E-...|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- prediction: double (nullable = true)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.77      0.66      0.71       170
#      Neutral       0.72      0.83      0.77       480
#     Positive       0.78      0.67      0.72       350
#
#     accuracy                           0.74      1000
#    macro avg       0.76      0.72      0.73      1000
# weighted avg       0.75      0.74      0.74      1000

# %% [markdown]
# - 5 epoch: 73, 72, 73
# - 10 epoch: 74, 71, 72
# - 15 epoch: 75, 71, 73
# - 20 epoch: 72, 72, 72
# ----------------------------
# - 5 epoch, batchsize = 32, lr=0.003: 74, 71, 72
# - 10 epoch, batchsize = 32, lr=0.003: 76, 73, 74 **Highest**
# - 15 epoch, batchsize = 32, lr=0.003: 74, 73, 73
# - 20 epoch, batchsize = 32, lr=0.003: 75, 73, 74
# ----------------------------
# - 5 epoch, batchsize = 8, lr=0.003: 16, 33, 22
# - 10 epoch, batchsize = 8, lr=0.003: 75, 74, 74
# - 15 epoch, batchsize = 8, lr=0.003: 74, 72, 73
# - 50 epoch, batchsize = 8, lr=0.003: 75, 72, 73
# ----------------------------
# - 5 epoch, batchsize = 16, lr=0.003: 75, 73, 73
# - 10 epoch, batchsize = 16, lr=0.003: 75, 72, 73
# - 15 epoch, batchsize = 16, lr=0.003: 73, 72, 72
# - 20 epoch, batchsize = 16, lr=0.003: 75, 73, 74

# %% [markdown]
# # **DistilBERT base model and ClassifierDLApproach (✔️)**
# https://nlp.johnsnowlabs.com/2021/05/20/distilbert_base_cased_en.html

# %%
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

sentence = SentenceDetector() \
          .setInputCols(['document']) \
          .setOutputCol('sentences')

token = Tokenizer() \
        .setInputCols(["sentences"]) \
        .setOutputCol("token")

#stop_words = StopWordsCleaner.pretrained('stopwords_en', 'en').setInputCols(["token"]).setOutputCol("cleanTokens").setCaseSensitive(False)

lemmatizer = LemmatizerModel.pretrained("lemma_antbnc", "en") \
            .setInputCols(["token"]) \
            .setOutputCol("lemma")

distilbert_embeddings = DistilBertEmbeddings.pretrained("distilbert_base_cased", "en") \
                  .setInputCols(["lemma","sentences"]) \
                  .setOutputCol("embeddings") \
                  .setCaseSensitive(False)

embeddingsSentence = SentenceEmbeddings() \
                    .setInputCols(["sentences", "embeddings"]) \
                    .setOutputCol("sentence_embeddings") \
                    .setPoolingStrategy("AVERAGE")

classifierdl = ClassifierDLApproach().setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction") \
              .setLabelColumn("sentiment") \
              .setBatchSize(64) \
              .setMaxEpochs(10) \
              .setLr(0.005) \
              .setEnableOutputLogs(True)

# classifierdl = ClassifierDLApproach().setInputCols(["embeddings"]) \
#               .setOutputCol("prediction") \
#               .setLabelColumn("sentiment") \
#               .setBatchSize(64) \
#               .setMaxEpochs(10) \
#               .setLr(0.005) \
#               .setEnableOutputLogs(True)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]
# distilbert_base_cased download started this may take some time.
# Approximate size to download 232.7 MB
# [OK!]

# %%
nlp_pipeline_distilbert = Pipeline(stages=[document,
                                          sentence,
                                          token,
                                          lemmatizer, 
                                          distilbert_embeddings,
                                          embeddingsSentence,
                                          classifierdl])

# %%
model_distilbert = nlp_pipeline_distilbert.fit(train)

predict_test = model_distilbert.transform(test)

# %%
predict_test.show(truncate=100)
#predict_test.select("sentence_embeddings").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |                                                                                                text|sentiment|                                                                                            document|                                                                                           sentences|                                                                                               token|                                                                                               lemma|                                                                                          embeddings|                                                                                 sentence_embeddings|                                                                                          prediction|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |  pfizerbiontech tozinameran has reported adverse reactions and at least deaths under death category|      0.0|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{word_embeddings, 0, 13, pfizerbiontech, {isOOV -> false, pieceId -> 185, isWordStart -> true, t...|[{sentence_embeddings, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at le...|[{category, 0, 97, 0.0, {sentence -> 0, 1.0 -> 4.0023857E-5, 0.0 -> 0.9999589, 2.0 -> 1.0889192E-...|
# |mom is doing panic buying whereas dad panic selling dad coronavirusindia covaxin coronaviruspandemic|      0.0|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, is, {sentence -> 0}, []}, {token, 7, 11, ...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, be, {sentence -> 0}, []}, {token, 7, 11, ...|[{word_embeddings, 0, 2, mom, {isOOV -> false, pieceId -> 4113, isWordStart -> true, token -> mom...|[{sentence_embeddings, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirus...|[{category, 0, 99, 2.0, {sentence -> 0, 1.0 -> 0.0034964953, 0.0 -> 1.615419E-4, 2.0 -> 0.996342}...|
# |today is my birthday for my gift my sons mother and i were able to get our first dose moderna vac...|      1.0|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, is, {sentence -> 0}, []}, {token, 9, 10...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, be, {sentence -> 0}, []}, {token, 9, 10...|[{word_embeddings, 0, 4, today, {isOOV -> false, pieceId -> 2052, isWordStart -> true, token -> t...|[{sentence_embeddings, 0, 146, today is my birthday for my gift my sons mother and i were able to...|[{category, 0, 146, 2.0, {sentence -> 0, 1.0 -> 1.210305E-4, 0.0 -> 6.251369E-7, 2.0 -> 0.9998783...|
# |                                            omi hospital karachi is charging rs for sputnikv vaccine|      1.0|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{word_embeddings, 0, 2, omi, {isOOV -> false, pieceId -> 184, isWordStart -> true, token -> omi,...|[{sentence_embeddings, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence...|[{category, 0, 55, 1.0, {sentence -> 0, 1.0 -> 0.99561864, 0.0 -> 1.6301241E-5, 2.0 -> 0.00436505...|
# |our beloved pm shri narendra modi takes his st covid shot covaxin today ok hand syringe covaxin c...|      2.0|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{token, 0, 2, our, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 1...|[{token, 0, 2, we, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 2, we, {isOOV -> false, pieceId -> 1195, isWordStart -> true, token -> we, ...|[{sentence_embeddings, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin ...|[{category, 0, 117, 1.0, {sentence -> 0, 1.0 -> 0.99793565, 0.0 -> 8.131469E-7, 2.0 -> 0.00206357...|
# |     super happy to get the moderna vaccine syringe no side effects whatsoever dose trophy thank you|      2.0|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, super, {isOOV -> false, pieceId -> 7688, isWordStart -> true, token -> s...|[{sentence_embeddings, 0, 94, super happy to get the moderna vaccine syringe no side effects what...|[{category, 0, 94, 2.0, {sentence -> 0, 1.0 -> 6.058474E-8, 0.0 -> 9.092565E-10, 2.0 -> 0.9999999...|
# |                covaxin s phase trials results likely next month read more covid india covid vaccine|      1.0|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{word_embeddings, 0, 6, covaxin, {isOOV -> false, pieceId -> 1884, isWordStart -> true, token ->...|[{sentence_embeddings, 0, 83, covaxin s phase trials results likely next month read more covid in...|[{category, 0, 83, 1.0, {sentence -> 0, 1.0 -> 0.76574355, 0.0 -> 2.2632117E-5, 2.0 -> 0.23423384...|
# |                          dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand|      1.0|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{word_embeddings, 0, 3, dose, {isOOV -> false, pieceId -> 13753, isWordStart -> true, token -> d...|[{sentence_embeddings, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur compl...|[{category, 0, 73, 1.0, {sentence -> 0, 1.0 -> 0.99999964, 0.0 -> 2.0053665E-8, 2.0 -> 3.4337404E...|
# |                    we call on usg to act with speed to trf vaccine tech for global scale up moderna|      1.0|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{word_embeddings, 0, 1, we, {isOOV -> false, pieceId -> 1195, isWordStart -> true, token -> we, ...|[{sentence_embeddings, 0, 79, we call on usg to act with speed to trf vaccine tech for global sca...|[{category, 0, 79, 1.0, {sentence -> 0, 1.0 -> 0.9861341, 0.0 -> 3.3737215E-6, 2.0 -> 0.013862473...|
# |    full vaccinated with moderna first shot no sides second arm a bit sore at injection site tired r|      0.0|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinated, {sentence -> 0}, []}, {toke...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinate, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 3, full, {isOOV -> false, pieceId -> 1554, isWordStart -> true, token -> fu...|[{sentence_embeddings, 0, 95, full vaccinated with moderna first shot no sides second arm a bit s...|[{category, 0, 95, 0.0, {sentence -> 0, 1.0 -> 0.013657818, 0.0 -> 0.98032343, 2.0 -> 0.006018762...|
# |                                     this laughing at how perfect this tweet is moderna modernablock|      1.0|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laughing, {sentence -> 0}, []}, {token,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laugh, {sentence -> 0}, []}, {token, 14...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> 1142, isWordStart -> true, token -> th...|[{sentence_embeddings, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {s...|[{category, 0, 62, 2.0, {sentence -> 0, 1.0 -> 0.040104013, 0.0 -> 0.2229885, 2.0 -> 0.7369074}, ...|
# |                                   i got vaccinated sinovac stdose frontliner nurse covidvaccination|      1.0|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, got, {sentence -> 0}, []}, {token, 6, 15, v...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, get, {sentence -> 0}, []}, {token, 6, 15, v...|[{word_embeddings, 0, 0, i, {isOOV -> false, pieceId -> 178, isWordStart -> true, token -> i, sen...|[{sentence_embeddings, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, ...|[{category, 0, 64, 2.0, {sentence -> 0, 1.0 -> 0.04411135, 0.0 -> 2.700493E-5, 2.0 -> 0.9558616},...|
# |                                                age d d slots covaxin on gvg invivo hospital rs bbmp|      1.0|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{word_embeddings, 0, 2, age, {isOOV -> false, pieceId -> 1425, isWordStart -> true, token -> age...|[{sentence_embeddings, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> ...|[{category, 0, 51, 1.0, {sentence -> 0, 1.0 -> 0.9999043, 0.0 -> 4.291341E-5, 2.0 -> 5.2834E-5}, ...|
# |                     this is bad news the first shot was bad enough my arm hurt for ten days moderna|      0.0|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, is, {sentence -> 0}, []}, {token, 8, 10,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, be, {sentence -> 0}, []}, {token, 8, 10,...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> 1142, isWordStart -> true, token -> th...|[{sentence_embeddings, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten ...|[{category, 0, 78, 0.0, {sentence -> 0, 1.0 -> 2.2597537E-4, 0.0 -> 0.99973565, 2.0 -> 3.8374743E...|
# |yep just guess who has bribed our governments more pfizer moderna astrazeneca it s all a sham no ...|      0.0|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{word_embeddings, 0, 2, yep, {isOOV -> false, pieceId -> 6798, isWordStart -> true, token -> yep...|[{sentence_embeddings, 0, 242, yep just guess who has bribed our governments more pfizer moderna ...|[{category, 0, 242, 1.0, {sentence -> 0, 1.0 -> 0.8632425, 0.0 -> 1.1336826E-5, 2.0 -> 0.13674618...|
# |with approval to rd vaccine sputnikv amp its roll out expected in a few weeks india s vaccination...|      1.0|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{word_embeddings, 0, 3, with, {isOOV -> false, pieceId -> 1114, isWordStart -> true, token -> wi...|[{sentence_embeddings, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in ...|[{category, 0, 241, 1.0, {sentence -> 0, 1.0 -> 0.82012, 0.0 -> 1.450321E-7, 2.0 -> 0.17987989}, ...|
# |delhi prime minister narendramodi takes his second dose of covid vaccine at aiims he received the...|      1.0|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, delhi, {isOOV -> false, pieceId -> 3687, isWordStart -> true, token -> d...|[{sentence_embeddings, 0, 193, delhi prime minister narendramodi takes his second dose of covid v...|[{category, 0, 193, 1.0, {sentence -> 0, 1.0 -> 0.9999422, 0.0 -> 5.2416002E-8, 2.0 -> 5.787259E-...|
# |china airplane chad chad is the latest african country that receives china donated sinopharm covi...|      1.0|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 4, china, {isOOV -> false, pieceId -> 5144, isWordStart -> true, token -> c...|[{sentence_embeddings, 0, 122, china airplane chad chad is the latest african country that receiv...|[{category, 0, 122, 1.0, {sentence -> 0, 1.0 -> 0.99836177, 0.0 -> 0.0014270103, 2.0 -> 2.112095E...|
# |group rolls out covid vaccination programme via vaccination covidvaccine frontlineworkers frontli...|      2.0|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, rolls, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, roll, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 4, group, {isOOV -> false, pieceId -> 1372, isWordStart -> true, token -> g...|[{sentence_embeddings, 0, 136, group rolls out covid vaccination programme via vaccination covidv...|[{category, 0, 136, 1.0, {sentence -> 0, 1.0 -> 0.9784782, 0.0 -> 1.3835371E-6, 2.0 -> 0.02152040...|
# |  russia s sputnikv vaccine to be produced by malaysia covid technologysharing gamaleya vaccinedeals|      1.0|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{word_embeddings, 0, 5, russia, {isOOV -> false, pieceId -> 187, isWordStart -> true, token -> r...|[{sentence_embeddings, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technolo...|[{category, 0, 97, 1.0, {sentence -> 0, 1.0 -> 0.99990225, 0.0 -> 2.6359266E-6, 2.0 -> 9.516315E-...|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- prediction: double (nullable = true)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.78      0.64      0.70       170
#      Neutral       0.73      0.78      0.75       480
#     Positive       0.73      0.73      0.73       350
#
#     accuracy                           0.74      1000
#    macro avg       0.75      0.71      0.73      1000
# weighted avg       0.74      0.74      0.74      1000

# %% [markdown]
# - epoch = 5: 0.16, 0.33, 0.22
# - epoch = 10: 0.75, 0.71, 0.73

# %% [markdown]
# # **RoBERTa and ClassifierDLApproach**

# %%
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

sentence = SentenceDetector() \
          .setInputCols(['document']) \
          .setOutputCol('sentences')

token = Tokenizer() \
        .setInputCols(["sentences"]) \
        .setOutputCol("token")

#stop_words = StopWordsCleaner.pretrained('stopwords_en', 'en').setInputCols(["token"]).setOutputCol("cleanTokens").setCaseSensitive(False)

lemmatizer = LemmatizerModel.pretrained("lemma_antbnc", "en") \
            .setInputCols(["token"]) \
            .setOutputCol("lemma")

roberta_embeddings = RoBertaEmbeddings.pretrained("roberta_base", "en") \
      .setInputCols("sentences", "lemma") \
      .setOutputCol("embeddings")

embeddingsSentence = SentenceEmbeddings() \
                    .setInputCols(["sentences", "embeddings"]) \
                    .setOutputCol("sentence_embeddings") \
                    .setPoolingStrategy("AVERAGE")

classifierdl = ClassifierDLApproach().setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction") \
              .setLabelColumn("sentiment") \
              .setBatchSize(64) \
              .setMaxEpochs(10) \
              .setLr(0.005) \
              .setEnableOutputLogs(True)

# embeddingsFinisher = EmbeddingsFinisher() \
#                     .setInputCols("embeddings") \
#                     .setOutputCols("finished_embeddings") \
#                     .setOutputAsVector(True) \
#                     .setCleanAnnotations(False)

# classifierdl = ClassifierDLApproach().setInputCols(["finished_embeddings"]) \
#               .setOutputCol("prediction") \
#               .setLabelColumn("sentiment") \
#               .setBatchSize(64) \
#               .setMaxEpochs(10) \
#               .setLr(0.005) \
#               .setEnableOutputLogs(True)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]
# roberta_base download started this may take some time.
# Approximate size to download 284.8 MB
# [OK!]

# %%
nlp_pipeline_roberta = Pipeline(stages=[document,
                                          sentence,
                                          token,
                                          lemmatizer, 
                                          roberta_embeddings,
                                          embeddingsSentence,
                                          classifierdl])

# %%
model_roberta = nlp_pipeline_roberta.fit(train)

predict_test = model_roberta.transform(test)

# %%
predict_test.show(truncate=100)
#predict_test.select("sentence_embeddings").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# |                                                                                                text|sentiment|                                                                                            document|                                                                                           sentences|                                                                                               token|                                                                                               lemma|                                                                                          embeddings|                                                                                 sentence_embeddings|                                                                        prediction|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# |  pfizerbiontech tozinameran has reported adverse reactions and at least deaths under death category|      0.0|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{word_embeddings, 0, 13, pfizerbiontech, {isOOV -> false, pieceId -> 181, isWordStart -> true, t...|[{sentence_embeddings, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at le...| [{category, 0, 97, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |mom is doing panic buying whereas dad panic selling dad coronavirusindia covaxin coronaviruspandemic|      0.0|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, is, {sentence -> 0}, []}, {token, 7, 11, ...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, be, {sentence -> 0}, []}, {token, 7, 11, ...|[{word_embeddings, 0, 2, mom, {isOOV -> false, pieceId -> 3795, isWordStart -> true, token -> mom...|[{sentence_embeddings, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirus...| [{category, 0, 99, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |today is my birthday for my gift my sons mother and i were able to get our first dose moderna vac...|      1.0|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, is, {sentence -> 0}, []}, {token, 9, 10...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, be, {sentence -> 0}, []}, {token, 9, 10...|[{word_embeddings, 0, 4, today, {isOOV -> false, pieceId -> 452, isWordStart -> true, token -> to...|[{sentence_embeddings, 0, 146, today is my birthday for my gift my sons mother and i were able to...|[{category, 0, 146, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                            omi hospital karachi is charging rs for sputnikv vaccine|      1.0|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{word_embeddings, 0, 2, omi, {isOOV -> false, pieceId -> 3, isWordStart -> true, token -> omi, s...|[{sentence_embeddings, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence...| [{category, 0, 55, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |our beloved pm shri narendra modi takes his st covid shot covaxin today ok hand syringe covaxin c...|      2.0|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{token, 0, 2, our, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 1...|[{token, 0, 2, we, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 2, we, {isOOV -> false, pieceId -> 52, isWordStart -> true, token -> we, se...|[{sentence_embeddings, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin ...|[{category, 0, 117, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |     super happy to get the moderna vaccine syringe no side effects whatsoever dose trophy thank you|      2.0|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, super, {isOOV -> false, pieceId -> 2422, isWordStart -> true, token -> s...|[{sentence_embeddings, 0, 94, super happy to get the moderna vaccine syringe no side effects what...| [{category, 0, 94, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                covaxin s phase trials results likely next month read more covid india covid vaccine|      1.0|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{word_embeddings, 0, 6, covaxin, {isOOV -> false, pieceId -> 740, isWordStart -> true, token -> ...|[{sentence_embeddings, 0, 83, covaxin s phase trials results likely next month read more covid in...| [{category, 0, 83, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                          dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand|      1.0|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{word_embeddings, 0, 3, dose, {isOOV -> false, pieceId -> 12234, isWordStart -> true, token -> d...|[{sentence_embeddings, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur compl...| [{category, 0, 73, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                    we call on usg to act with speed to trf vaccine tech for global scale up moderna|      1.0|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{word_embeddings, 0, 1, we, {isOOV -> false, pieceId -> 52, isWordStart -> true, token -> we, se...|[{sentence_embeddings, 0, 79, we call on usg to act with speed to trf vaccine tech for global sca...| [{category, 0, 79, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |    full vaccinated with moderna first shot no sides second arm a bit sore at injection site tired r|      0.0|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinated, {sentence -> 0}, []}, {toke...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinate, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 3, full, {isOOV -> false, pieceId -> 455, isWordStart -> true, token -> ful...|[{sentence_embeddings, 0, 95, full vaccinated with moderna first shot no sides second arm a bit s...| [{category, 0, 95, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                     this laughing at how perfect this tweet is moderna modernablock|      1.0|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laughing, {sentence -> 0}, []}, {token,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laugh, {sentence -> 0}, []}, {token, 14...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> 42, isWordStart -> true, token -> this...|[{sentence_embeddings, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {s...| [{category, 0, 62, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                   i got vaccinated sinovac stdose frontliner nurse covidvaccination|      1.0|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, got, {sentence -> 0}, []}, {token, 6, 15, v...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, get, {sentence -> 0}, []}, {token, 6, 15, v...|[{word_embeddings, 0, 0, i, {isOOV -> false, pieceId -> 939, isWordStart -> true, token -> i, sen...|[{sentence_embeddings, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, ...| [{category, 0, 64, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                                age d d slots covaxin on gvg invivo hospital rs bbmp|      1.0|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{word_embeddings, 0, 2, age, {isOOV -> false, pieceId -> 1046, isWordStart -> true, token -> age...|[{sentence_embeddings, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> ...| [{category, 0, 51, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                     this is bad news the first shot was bad enough my arm hurt for ten days moderna|      0.0|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, is, {sentence -> 0}, []}, {token, 8, 10,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, be, {sentence -> 0}, []}, {token, 8, 10,...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> 42, isWordStart -> true, token -> this...|[{sentence_embeddings, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten ...| [{category, 0, 78, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |yep just guess who has bribed our governments more pfizer moderna astrazeneca it s all a sham no ...|      0.0|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{word_embeddings, 0, 2, yep, {isOOV -> false, pieceId -> 1423, isWordStart -> true, token -> yep...|[{sentence_embeddings, 0, 242, yep just guess who has bribed our governments more pfizer moderna ...|[{category, 0, 242, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |with approval to rd vaccine sputnikv amp its roll out expected in a few weeks india s vaccination...|      1.0|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{word_embeddings, 0, 3, with, {isOOV -> false, pieceId -> 19, isWordStart -> true, token -> with...|[{sentence_embeddings, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in ...|[{category, 0, 241, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |delhi prime minister narendramodi takes his second dose of covid vaccine at aiims he received the...|      1.0|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, delhi, {isOOV -> false, pieceId -> 2424, isWordStart -> true, token -> d...|[{sentence_embeddings, 0, 193, delhi prime minister narendramodi takes his second dose of covid v...|[{category, 0, 193, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |china airplane chad chad is the latest african country that receives china donated sinopharm covi...|      1.0|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 4, china, {isOOV -> false, pieceId -> 1855, isWordStart -> true, token -> c...|[{sentence_embeddings, 0, 122, china airplane chad chad is the latest african country that receiv...|[{category, 0, 122, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |group rolls out covid vaccination programme via vaccination covidvaccine frontlineworkers frontli...|      2.0|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, rolls, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, roll, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 4, group, {isOOV -> false, pieceId -> 333, isWordStart -> true, token -> gr...|[{sentence_embeddings, 0, 136, group rolls out covid vaccination programme via vaccination covidv...|[{category, 0, 136, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |  russia s sputnikv vaccine to be produced by malaysia covid technologysharing gamaleya vaccinedeals|      1.0|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{word_embeddings, 0, 5, russia, {isOOV -> false, pieceId -> 910, isWordStart -> true, token -> r...|[{sentence_embeddings, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technolo...| [{category, 0, 97, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- prediction: double (nullable = true)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00       170
#      Neutral       0.48      1.00      0.65       480
#     Positive       0.00      0.00      0.00       350
#
#     accuracy                           0.48      1000
#    macro avg       0.16      0.33      0.22      1000
# weighted avg       0.23      0.48      0.31      1000
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# - epoch = 10: 0.12, 0.33, 0.17

# %% [markdown]
# # **XLM-RoBERTa and ClassifierDLApproach**

# %%
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

sentence = SentenceDetector() \
          .setInputCols(['document']) \
          .setOutputCol('sentences')

token = Tokenizer() \
        .setInputCols(["sentences"]) \
        .setOutputCol("token")

#stop_words = StopWordsCleaner.pretrained('stopwords_en', 'en').setInputCols(["token"]).setOutputCol("cleanTokens").setCaseSensitive(False)

lemmatizer = LemmatizerModel.pretrained("lemma_antbnc", "en") \
            .setInputCols(["token"]) \
            .setOutputCol("lemma")

xlmroberta_embeddings = XlmRoBertaEmbeddings.pretrained("xlm_roberta_base", "xx") \
      .setInputCols("sentences", "lemma") \
      .setOutputCol("embeddings")

embeddingsSentence = SentenceEmbeddings() \
                    .setInputCols(["sentences", "embeddings"]) \
                    .setOutputCol("sentence_embeddings") \
                    .setPoolingStrategy("AVERAGE")

classifierdl = ClassifierDLApproach().setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction") \
              .setLabelColumn("sentiment") \
              .setBatchSize(64) \
              .setMaxEpochs(10) \
              .setLr(0.005) \
              .setEnableOutputLogs(True)

# classifierdl = ClassifierDLApproach().setInputCols(["embeddings"]) \
#               .setOutputCol("prediction") \
#               .setLabelColumn("sentiment") \
#               .setBatchSize(64) \
#               .setMaxEpochs(10) \
#               .setLr(0.005) \
#               .setEnableOutputLogs(True)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]
# xlm_roberta_base download started this may take some time.
# Approximate size to download 619.5 MB
# [OK!]

# %%
nlp_pipeline_xlmroberta = Pipeline(stages=[document,
                                          sentence,
                                          token,
                                          lemmatizer, 
                                          xlmroberta_embeddings,
                                          embeddingsSentence,
                                          classifierdl])

# %%
model_xlmroberta = nlp_pipeline_xlmroberta.fit(train)

predict_test = model_xlmroberta.transform(test)

# %%
predict_test.show(truncate=100)
#predict_test.select("sentence_embeddings").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# |                                                                                                text|sentiment|                                                                                            document|                                                                                           sentences|                                                                                               token|                                                                                               lemma|                                                                                          embeddings|                                                                                 sentence_embeddings|                                                                        prediction|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# |  pfizerbiontech tozinameran has reported adverse reactions and at least deaths under death category|      0.0|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{word_embeddings, 0, 13, pfizerbiontech, {isOOV -> false, pieceId -> 915, isWordStart -> true, t...|[{sentence_embeddings, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at le...| [{category, 0, 97, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |mom is doing panic buying whereas dad panic selling dad coronavirusindia covaxin coronaviruspandemic|      0.0|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, is, {sentence -> 0}, []}, {token, 7, 11, ...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, be, {sentence -> 0}, []}, {token, 7, 11, ...|[{word_embeddings, 0, 2, mom, {isOOV -> false, pieceId -> 32318, isWordStart -> true, token -> mo...|[{sentence_embeddings, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirus...| [{category, 0, 99, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |today is my birthday for my gift my sons mother and i were able to get our first dose moderna vac...|      1.0|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, is, {sentence -> 0}, []}, {token, 9, 10...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, be, {sentence -> 0}, []}, {token, 9, 10...|[{word_embeddings, 0, 4, today, {isOOV -> false, pieceId -> 18925, isWordStart -> true, token -> ...|[{sentence_embeddings, 0, 146, today is my birthday for my gift my sons mother and i were able to...|[{category, 0, 146, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                            omi hospital karachi is charging rs for sputnikv vaccine|      1.0|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{word_embeddings, 0, 2, omi, {isOOV -> false, pieceId -> 171, isWordStart -> true, token -> omi,...|[{sentence_embeddings, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence...| [{category, 0, 55, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |our beloved pm shri narendra modi takes his st covid shot covaxin today ok hand syringe covaxin c...|      2.0|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{token, 0, 2, our, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 1...|[{token, 0, 2, we, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 2, we, {isOOV -> false, pieceId -> 642, isWordStart -> true, token -> we, s...|[{sentence_embeddings, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin ...|[{category, 0, 117, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |     super happy to get the moderna vaccine syringe no side effects whatsoever dose trophy thank you|      2.0|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, super, {isOOV -> false, pieceId -> 1601, isWordStart -> true, token -> s...|[{sentence_embeddings, 0, 94, super happy to get the moderna vaccine syringe no side effects what...| [{category, 0, 94, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                covaxin s phase trials results likely next month read more covid india covid vaccine|      1.0|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{word_embeddings, 0, 6, covaxin, {isOOV -> false, pieceId -> 552, isWordStart -> true, token -> ...|[{sentence_embeddings, 0, 83, covaxin s phase trials results likely next month read more covid in...| [{category, 0, 83, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                          dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand|      1.0|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{word_embeddings, 0, 3, dose, {isOOV -> false, pieceId -> 39098, isWordStart -> true, token -> d...|[{sentence_embeddings, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur compl...| [{category, 0, 73, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                    we call on usg to act with speed to trf vaccine tech for global scale up moderna|      1.0|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{word_embeddings, 0, 1, we, {isOOV -> false, pieceId -> 642, isWordStart -> true, token -> we, s...|[{sentence_embeddings, 0, 79, we call on usg to act with speed to trf vaccine tech for global sca...| [{category, 0, 79, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |    full vaccinated with moderna first shot no sides second arm a bit sore at injection site tired r|      0.0|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinated, {sentence -> 0}, []}, {toke...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinate, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 3, full, {isOOV -> false, pieceId -> 4393, isWordStart -> true, token -> fu...|[{sentence_embeddings, 0, 95, full vaccinated with moderna first shot no sides second arm a bit s...| [{category, 0, 95, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                     this laughing at how perfect this tweet is moderna modernablock|      1.0|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laughing, {sentence -> 0}, []}, {token,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laugh, {sentence -> 0}, []}, {token, 14...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> 903, isWordStart -> true, token -> thi...|[{sentence_embeddings, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {s...| [{category, 0, 62, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                   i got vaccinated sinovac stdose frontliner nurse covidvaccination|      1.0|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, got, {sentence -> 0}, []}, {token, 6, 15, v...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, get, {sentence -> 0}, []}, {token, 6, 15, v...|[{word_embeddings, 0, 0, i, {isOOV -> false, pieceId -> 17, isWordStart -> true, token -> i, sent...|[{sentence_embeddings, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, ...| [{category, 0, 64, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                                age d d slots covaxin on gvg invivo hospital rs bbmp|      1.0|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{word_embeddings, 0, 2, age, {isOOV -> false, pieceId -> 32070, isWordStart -> true, token -> ag...|[{sentence_embeddings, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> ...| [{category, 0, 51, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                     this is bad news the first shot was bad enough my arm hurt for ten days moderna|      0.0|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, is, {sentence -> 0}, []}, {token, 8, 10,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, be, {sentence -> 0}, []}, {token, 8, 10,...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> 903, isWordStart -> true, token -> thi...|[{sentence_embeddings, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten ...| [{category, 0, 78, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |yep just guess who has bribed our governments more pfizer moderna astrazeneca it s all a sham no ...|      0.0|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{word_embeddings, 0, 2, yep, {isOOV -> false, pieceId -> 113, isWordStart -> true, token -> yep,...|[{sentence_embeddings, 0, 242, yep just guess who has bribed our governments more pfizer moderna ...|[{category, 0, 242, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |with approval to rd vaccine sputnikv amp its roll out expected in a few weeks india s vaccination...|      1.0|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{word_embeddings, 0, 3, with, {isOOV -> false, pieceId -> 678, isWordStart -> true, token -> wit...|[{sentence_embeddings, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in ...|[{category, 0, 241, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |delhi prime minister narendramodi takes his second dose of covid vaccine at aiims he received the...|      1.0|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, delhi, {isOOV -> false, pieceId -> 146, isWordStart -> true, token -> de...|[{sentence_embeddings, 0, 193, delhi prime minister narendramodi takes his second dose of covid v...|[{category, 0, 193, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |china airplane chad chad is the latest african country that receives china donated sinopharm covi...|      1.0|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 4, china, {isOOV -> false, pieceId -> 42072, isWordStart -> true, token -> ...|[{sentence_embeddings, 0, 122, china airplane chad chad is the latest african country that receiv...|[{category, 0, 122, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |group rolls out covid vaccination programme via vaccination covidvaccine frontlineworkers frontli...|      2.0|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, rolls, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, roll, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 4, group, {isOOV -> false, pieceId -> 21115, isWordStart -> true, token -> ...|[{sentence_embeddings, 0, 136, group rolls out covid vaccination programme via vaccination covidv...|[{category, 0, 136, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |  russia s sputnikv vaccine to be produced by malaysia covid technologysharing gamaleya vaccinedeals|      1.0|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{word_embeddings, 0, 5, russia, {isOOV -> false, pieceId -> 7793, isWordStart -> true, token -> ...|[{sentence_embeddings, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technolo...| [{category, 0, 97, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- prediction: double (nullable = true)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00       170
#      Neutral       0.48      1.00      0.65       480
#     Positive       0.00      0.00      0.00       350
#
#     accuracy                           0.48      1000
#    macro avg       0.16      0.33      0.22      1000
# weighted avg       0.23      0.48      0.31      1000
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# - epoch = 10: 0.16, 0.33, 0.22 (l2: 0.12, 0.33, 0.17)

# %% [markdown]
# # **XLNet and ClassifierDLApproach**

# %%
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

sentence = SentenceDetector() \
          .setInputCols(['document']) \
          .setOutputCol('sentences')

token = Tokenizer() \
        .setInputCols(["sentences"]) \
        .setOutputCol("token")

#stop_words = StopWordsCleaner.pretrained('stopwords_en', 'en').setInputCols(["token"]).setOutputCol("cleanTokens").setCaseSensitive(False)

lemmatizer = LemmatizerModel.pretrained("lemma_antbnc", "en") \
            .setInputCols(["token"]) \
            .setOutputCol("lemma")

xlnet_embeddings = XlnetEmbeddings.pretrained("xlnet_base_cased", "en") \
      .setInputCols("sentences", "lemma") \
      .setOutputCol("embeddings")

embeddingsSentence = SentenceEmbeddings() \
                    .setInputCols(["sentences", "embeddings"]) \
                    .setOutputCol("sentence_embeddings") \
                    .setPoolingStrategy("AVERAGE")

classifierdl = ClassifierDLApproach().setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction") \
              .setLabelColumn("sentiment") \
              .setBatchSize(64) \
              .setMaxEpochs(10) \
              .setLr(0.005) \
              .setEnableOutputLogs(True)

# classifierdl = ClassifierDLApproach().setInputCols(["embeddings"]) \
#               .setOutputCol("prediction") \
#               .setLabelColumn("sentiment") \
#               .setBatchSize(64) \
#               .setMaxEpochs(10) \
#               .setLr(0.005) \
#               .setEnableOutputLogs(True)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]
# xlnet_base_cased download started this may take some time.
# Approximate size to download 417.5 MB
# [OK!]

# %%
nlp_pipeline_xlnet = Pipeline(stages=[document,
                                          sentence,
                                          token,
                                          lemmatizer, 
                                          xlnet_embeddings,
                                          embeddingsSentence,
                                          classifierdl])

# %%
model_xlnet = nlp_pipeline_xlnet.fit(train)

predict_test = model_xlnet.transform(test)

# %%
predict_test.show(truncate=100)
#predict_test.select("sentence_embeddings").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# |                                                                                                text|sentiment|                                                                                            document|                                                                                           sentences|                                                                                               token|                                                                                               lemma|                                                                                          embeddings|                                                                                 sentence_embeddings|                                                                        prediction|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# |  pfizerbiontech tozinameran has reported adverse reactions and at least deaths under death category|      0.0|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{word_embeddings, 0, 13, pfizerbiontech, {isOOV -> false, pieceId -> 21225, isWordStart -> true,...|[{sentence_embeddings, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at le...| [{category, 0, 97, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |mom is doing panic buying whereas dad panic selling dad coronavirusindia covaxin coronaviruspandemic|      0.0|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, is, {sentence -> 0}, []}, {token, 7, 11, ...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, be, {sentence -> 0}, []}, {token, 7, 11, ...|[{word_embeddings, 0, 2, mom, {isOOV -> false, pieceId -> 4489, isWordStart -> true, token -> mom...|[{sentence_embeddings, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirus...| [{category, 0, 99, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |today is my birthday for my gift my sons mother and i were able to get our first dose moderna vac...|      1.0|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, is, {sentence -> 0}, []}, {token, 9, 10...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, be, {sentence -> 0}, []}, {token, 9, 10...|[{word_embeddings, 0, 4, today, {isOOV -> false, pieceId -> 494, isWordStart -> true, token -> to...|[{sentence_embeddings, 0, 146, today is my birthday for my gift my sons mother and i were able to...|[{category, 0, 146, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |                                            omi hospital karachi is charging rs for sputnikv vaccine|      1.0|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{word_embeddings, 0, 2, omi, {isOOV -> false, pieceId -> 13154, isWordStart -> true, token -> om...|[{sentence_embeddings, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence...| [{category, 0, 55, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |our beloved pm shri narendra modi takes his st covid shot covaxin today ok hand syringe covaxin c...|      2.0|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{token, 0, 2, our, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 1...|[{token, 0, 2, we, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 2, we, {isOOV -> false, pieceId -> 80, isWordStart -> true, token -> we, se...|[{sentence_embeddings, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin ...|[{category, 0, 117, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |     super happy to get the moderna vaccine syringe no side effects whatsoever dose trophy thank you|      2.0|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, super, {isOOV -> false, pieceId -> 2653, isWordStart -> true, token -> s...|[{sentence_embeddings, 0, 94, super happy to get the moderna vaccine syringe no side effects what...| [{category, 0, 94, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |                covaxin s phase trials results likely next month read more covid india covid vaccine|      1.0|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{word_embeddings, 0, 6, covaxin, {isOOV -> false, pieceId -> 830, isWordStart -> true, token -> ...|[{sentence_embeddings, 0, 83, covaxin s phase trials results likely next month read more covid in...| [{category, 0, 83, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |                          dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand|      1.0|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{word_embeddings, 0, 3, dose, {isOOV -> false, pieceId -> 7540, isWordStart -> true, token -> do...|[{sentence_embeddings, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur compl...| [{category, 0, 73, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |                    we call on usg to act with speed to trf vaccine tech for global scale up moderna|      1.0|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{word_embeddings, 0, 1, we, {isOOV -> false, pieceId -> 80, isWordStart -> true, token -> we, se...|[{sentence_embeddings, 0, 79, we call on usg to act with speed to trf vaccine tech for global sca...| [{category, 0, 79, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |    full vaccinated with moderna first shot no sides second arm a bit sore at injection site tired r|      0.0|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinated, {sentence -> 0}, []}, {toke...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinate, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 3, full, {isOOV -> false, pieceId -> 410, isWordStart -> true, token -> ful...|[{sentence_embeddings, 0, 95, full vaccinated with moderna first shot no sides second arm a bit s...| [{category, 0, 95, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |                                     this laughing at how perfect this tweet is moderna modernablock|      1.0|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laughing, {sentence -> 0}, []}, {token,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laugh, {sentence -> 0}, []}, {token, 14...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> 52, isWordStart -> true, token -> this...|[{sentence_embeddings, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {s...| [{category, 0, 62, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |                                   i got vaccinated sinovac stdose frontliner nurse covidvaccination|      1.0|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, got, {sentence -> 0}, []}, {token, 6, 15, v...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, get, {sentence -> 0}, []}, {token, 6, 15, v...|[{word_embeddings, 0, 0, i, {isOOV -> false, pieceId -> 150, isWordStart -> true, token -> i, sen...|[{sentence_embeddings, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, ...| [{category, 0, 64, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |                                                age d d slots covaxin on gvg invivo hospital rs bbmp|      1.0|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{word_embeddings, 0, 2, age, {isOOV -> false, pieceId -> 679, isWordStart -> true, token -> age,...|[{sentence_embeddings, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> ...| [{category, 0, 51, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |                     this is bad news the first shot was bad enough my arm hurt for ten days moderna|      0.0|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, is, {sentence -> 0}, []}, {token, 8, 10,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, be, {sentence -> 0}, []}, {token, 8, 10,...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> 52, isWordStart -> true, token -> this...|[{sentence_embeddings, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten ...| [{category, 0, 78, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |yep just guess who has bribed our governments more pfizer moderna astrazeneca it s all a sham no ...|      0.0|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{word_embeddings, 0, 2, yep, {isOOV -> false, pieceId -> 117, isWordStart -> true, token -> yep,...|[{sentence_embeddings, 0, 242, yep just guess who has bribed our governments more pfizer moderna ...|[{category, 0, 242, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |with approval to rd vaccine sputnikv amp its roll out expected in a few weeks india s vaccination...|      1.0|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{word_embeddings, 0, 3, with, {isOOV -> false, pieceId -> 33, isWordStart -> true, token -> with...|[{sentence_embeddings, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in ...|[{category, 0, 241, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |delhi prime minister narendramodi takes his second dose of covid vaccine at aiims he received the...|      1.0|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, delhi, {isOOV -> false, pieceId -> 5974, isWordStart -> true, token -> d...|[{sentence_embeddings, 0, 193, delhi prime minister narendramodi takes his second dose of covid v...|[{category, 0, 193, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |china airplane chad chad is the latest african country that receives china donated sinopharm covi...|      1.0|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 4, china, {isOOV -> false, pieceId -> 18252, isWordStart -> true, token -> ...|[{sentence_embeddings, 0, 122, china airplane chad chad is the latest african country that receiv...|[{category, 0, 122, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |group rolls out covid vaccination programme via vaccination covidvaccine frontlineworkers frontli...|      2.0|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, rolls, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, roll, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 4, group, {isOOV -> false, pieceId -> 256, isWordStart -> true, token -> gr...|[{sentence_embeddings, 0, 136, group rolls out covid vaccination programme via vaccination covidv...|[{category, 0, 136, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# |  russia s sputnikv vaccine to be produced by malaysia covid technologysharing gamaleya vaccinedeals|      1.0|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{word_embeddings, 0, 5, russia, {isOOV -> false, pieceId -> 7488, isWordStart -> true, token -> ...|[{sentence_embeddings, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technolo...| [{category, 0, 97, 2.0, {sentence -> 0, 1.0 -> 0.0, 0.0 -> 0.0, 2.0 -> 1.0}, []}]|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- prediction: double (nullable = true)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00       170
#      Neutral       0.00      0.00      0.00       480
#     Positive       0.35      1.00      0.52       350
#
#     accuracy                           0.35      1000
#    macro avg       0.12      0.33      0.17      1000
# weighted avg       0.12      0.35      0.18      1000
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# - epoch = 10: 12, 33, 17

# %% [markdown]
# # **BERT-base uncased and ClassifierDLApproach**

# %%
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

sentence = SentenceDetector() \
          .setInputCols(['document']) \
          .setOutputCol('sentences')

token = Tokenizer() \
        .setInputCols(["sentences"]) \
        .setOutputCol("token")

#stop_words = StopWordsCleaner.pretrained('stopwords_en', 'en').setInputCols(["token"]).setOutputCol("cleanTokens").setCaseSensitive(False)

lemmatizer = LemmatizerModel.pretrained("lemma_antbnc", "en") \
            .setInputCols(["token"]) \
            .setOutputCol("lemma")

bertbase_embeddings = BertEmbeddings.pretrained("bert_base_uncased", "en") \
                  .setInputCols(["sentences","lemma"]) \
                  .setOutputCol("embeddings") \
                  .setCaseSensitive(False)

embeddingsSentence = SentenceEmbeddings() \
                    .setInputCols(["sentences", "embeddings"]) \
                    .setOutputCol("sentence_embeddings") \
                    .setPoolingStrategy("AVERAGE")

classifierdl = ClassifierDLApproach().setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction") \
              .setLabelColumn("sentiment") \
              .setBatchSize(64) \
              .setMaxEpochs(5) \
              .setLr(0.005) \
              .setEnableOutputLogs(True)


# classifierdl = ClassifierDLApproach().setInputCols(["embeddings"]) \
#               .setOutputCol("prediction") \
#               .setLabelColumn("sentiment") \
#               .setBatchSize(32) \
#               .setMaxEpochs(5) \
#               .setLr(0.005) \
#               .setEnableOutputLogs(True)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]
# bert_base_uncased download started this may take some time.
# Approximate size to download 392.5 MB
# [OK!]

# %%
nlp_pipeline_bertbaseuncased = Pipeline(stages=[document,
                                          sentence,
                                          token,
                                          lemmatizer, 
                                          bertbase_embeddings,
                                          embeddingsSentence,
                                          classifierdl])

# %%
model_bertbaseuncased = nlp_pipeline_bertbaseuncased.fit(train)

predict_test = model_bertbaseuncased.transform(test)

# %%
predict_test.show(truncate=100)
#predict_test.select("sentence_embeddings").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# |                                                                                                text|sentiment|                                                                                            document|                                                                                           sentences|                                                                                               token|                                                                                               lemma|                                                                                          embeddings|                                                                                 sentence_embeddings|                                                                        prediction|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# |  pfizerbiontech tozinameran has reported adverse reactions and at least deaths under death category|      0.0|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{word_embeddings, 0, 13, pfizerbiontech, {isOOV -> false, pieceId -> 1052, isWordStart -> true, ...|[{sentence_embeddings, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at le...| [{category, 0, 97, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |mom is doing panic buying whereas dad panic selling dad coronavirusindia covaxin coronaviruspandemic|      0.0|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, is, {sentence -> 0}, []}, {token, 7, 11, ...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, be, {sentence -> 0}, []}, {token, 7, 11, ...|[{word_embeddings, 0, 2, mom, {isOOV -> false, pieceId -> 3566, isWordStart -> true, token -> mom...|[{sentence_embeddings, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirus...| [{category, 0, 99, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |today is my birthday for my gift my sons mother and i were able to get our first dose moderna vac...|      1.0|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, is, {sentence -> 0}, []}, {token, 9, 10...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, be, {sentence -> 0}, []}, {token, 9, 10...|[{word_embeddings, 0, 4, today, {isOOV -> false, pieceId -> 2651, isWordStart -> true, token -> t...|[{sentence_embeddings, 0, 146, today is my birthday for my gift my sons mother and i were able to...|[{category, 0, 146, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                            omi hospital karachi is charging rs for sputnikv vaccine|      1.0|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{word_embeddings, 0, 2, omi, {isOOV -> false, pieceId -> 18168, isWordStart -> true, token -> om...|[{sentence_embeddings, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence...| [{category, 0, 55, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |our beloved pm shri narendra modi takes his st covid shot covaxin today ok hand syringe covaxin c...|      2.0|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{token, 0, 2, our, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 1...|[{token, 0, 2, we, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 2, we, {isOOV -> false, pieceId -> 2057, isWordStart -> true, token -> we, ...|[{sentence_embeddings, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin ...|[{category, 0, 117, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |     super happy to get the moderna vaccine syringe no side effects whatsoever dose trophy thank you|      2.0|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, super, {isOOV -> false, pieceId -> 3565, isWordStart -> true, token -> s...|[{sentence_embeddings, 0, 94, super happy to get the moderna vaccine syringe no side effects what...| [{category, 0, 94, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                covaxin s phase trials results likely next month read more covid india covid vaccine|      1.0|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{word_embeddings, 0, 6, covaxin, {isOOV -> false, pieceId -> 2522, isWordStart -> true, token ->...|[{sentence_embeddings, 0, 83, covaxin s phase trials results likely next month read more covid in...| [{category, 0, 83, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                          dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand|      1.0|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{word_embeddings, 0, 3, dose, {isOOV -> false, pieceId -> 13004, isWordStart -> true, token -> d...|[{sentence_embeddings, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur compl...| [{category, 0, 73, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                    we call on usg to act with speed to trf vaccine tech for global scale up moderna|      1.0|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{word_embeddings, 0, 1, we, {isOOV -> false, pieceId -> 2057, isWordStart -> true, token -> we, ...|[{sentence_embeddings, 0, 79, we call on usg to act with speed to trf vaccine tech for global sca...| [{category, 0, 79, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |    full vaccinated with moderna first shot no sides second arm a bit sore at injection site tired r|      0.0|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinated, {sentence -> 0}, []}, {toke...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinate, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 3, full, {isOOV -> false, pieceId -> 2440, isWordStart -> true, token -> fu...|[{sentence_embeddings, 0, 95, full vaccinated with moderna first shot no sides second arm a bit s...| [{category, 0, 95, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                     this laughing at how perfect this tweet is moderna modernablock|      1.0|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laughing, {sentence -> 0}, []}, {token,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laugh, {sentence -> 0}, []}, {token, 14...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> 2023, isWordStart -> true, token -> th...|[{sentence_embeddings, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {s...| [{category, 0, 62, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                   i got vaccinated sinovac stdose frontliner nurse covidvaccination|      1.0|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, got, {sentence -> 0}, []}, {token, 6, 15, v...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, get, {sentence -> 0}, []}, {token, 6, 15, v...|[{word_embeddings, 0, 0, i, {isOOV -> false, pieceId -> 1045, isWordStart -> true, token -> i, se...|[{sentence_embeddings, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, ...| [{category, 0, 64, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                                age d d slots covaxin on gvg invivo hospital rs bbmp|      1.0|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{word_embeddings, 0, 2, age, {isOOV -> false, pieceId -> 2287, isWordStart -> true, token -> age...|[{sentence_embeddings, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> ...| [{category, 0, 51, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                     this is bad news the first shot was bad enough my arm hurt for ten days moderna|      0.0|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, is, {sentence -> 0}, []}, {token, 8, 10,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, be, {sentence -> 0}, []}, {token, 8, 10,...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> 2023, isWordStart -> true, token -> th...|[{sentence_embeddings, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten ...| [{category, 0, 78, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |yep just guess who has bribed our governments more pfizer moderna astrazeneca it s all a sham no ...|      0.0|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{word_embeddings, 0, 2, yep, {isOOV -> false, pieceId -> 15624, isWordStart -> true, token -> ye...|[{sentence_embeddings, 0, 242, yep just guess who has bribed our governments more pfizer moderna ...|[{category, 0, 242, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |with approval to rd vaccine sputnikv amp its roll out expected in a few weeks india s vaccination...|      1.0|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{word_embeddings, 0, 3, with, {isOOV -> false, pieceId -> 2007, isWordStart -> true, token -> wi...|[{sentence_embeddings, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in ...|[{category, 0, 241, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |delhi prime minister narendramodi takes his second dose of covid vaccine at aiims he received the...|      1.0|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, delhi, {isOOV -> false, pieceId -> 6768, isWordStart -> true, token -> d...|[{sentence_embeddings, 0, 193, delhi prime minister narendramodi takes his second dose of covid v...|[{category, 0, 193, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |china airplane chad chad is the latest african country that receives china donated sinopharm covi...|      1.0|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 4, china, {isOOV -> false, pieceId -> 2859, isWordStart -> true, token -> c...|[{sentence_embeddings, 0, 122, china airplane chad chad is the latest african country that receiv...|[{category, 0, 122, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |group rolls out covid vaccination programme via vaccination covidvaccine frontlineworkers frontli...|      2.0|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, rolls, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, roll, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 4, group, {isOOV -> false, pieceId -> 2177, isWordStart -> true, token -> g...|[{sentence_embeddings, 0, 136, group rolls out covid vaccination programme via vaccination covidv...|[{category, 0, 136, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |  russia s sputnikv vaccine to be produced by malaysia covid technologysharing gamaleya vaccinedeals|      1.0|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{word_embeddings, 0, 5, russia, {isOOV -> false, pieceId -> 3607, isWordStart -> true, token -> ...|[{sentence_embeddings, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technolo...| [{category, 0, 97, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- prediction: double (nullable = true)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00       170
#      Neutral       0.48      1.00      0.65       480
#     Positive       0.00      0.00      0.00       350
#
#     accuracy                           0.48      1000
#    macro avg       0.16      0.33      0.22      1000
# weighted avg       0.23      0.48      0.31      1000
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# - epoch = 5, batchsize = 32, lr = 0.005: 0.16, 0.33, 0.22
# - epoch = 10, batchsize = 32, lr = 0.005: 0.16, 0.33, 0.22
# - epoch = 5, batchsize = 64, lr = 0.005: 0.16, 0.33, 0.22
# - epoch = 10, batchsize = 64, lr = 0.005: 0.16, 0.33, 0.22

# %% [markdown]
# # **Elmo and ClassifierDLApproach**

# %%
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

sentence = SentenceDetector() \
          .setInputCols(['document']) \
          .setOutputCol('sentences')

token = Tokenizer() \
        .setInputCols(["sentences"]) \
        .setOutputCol("token")

#stop_words = StopWordsCleaner.pretrained('stopwords_en', 'en').setInputCols(["token"]).setOutputCol("cleanTokens").setCaseSensitive(False)

lemmatizer = LemmatizerModel.pretrained("lemma_antbnc", "en") \
            .setInputCols(["token"]) \
            .setOutputCol("lemma")

elmo_embeddings = ElmoEmbeddings.pretrained("elmo", "en") \
      .setInputCols(["sentences", "lemma"]) \
      .setOutputCol("embeddings") \
      .setPoolingLayer("elmo")

embeddingsSentence = SentenceEmbeddings() \
                    .setInputCols(["sentences", "embeddings"]) \
                    .setOutputCol("sentence_embeddings") \
                    .setPoolingStrategy("AVERAGE")

classifierdl = ClassifierDLApproach().setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction") \
              .setLabelColumn("sentiment") \
              .setBatchSize(64) \
              .setMaxEpochs(10) \
              .setLr(0.005) \
              .setEnableOutputLogs(True)

# classifierdl = ClassifierDLApproach().setInputCols(["embeddings"]) \
#               .setOutputCol("prediction") \
#               .setLabelColumn("sentiment") \
#               .setBatchSize(64) \
#               .setMaxEpochs(5) \
#               .setLr(0.005) \
#               .setEnableOutputLogs(True)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]
# elmo download started this may take some time.
# Approximate size to download 334.1 MB
# [OK!]

# %%
nlp_pipeline_elmo = Pipeline(stages=[document,
                                          sentence,
                                          token,
                                          lemmatizer, 
                                          elmo_embeddings,
                                          embeddingsSentence,
                                          classifierdl])

# %%
model_elmo = nlp_pipeline_elmo.fit(train)

predict_test = model_elmo.transform(test)

# %%
predict_test.show(truncate=100)
#predict_test.select("sentence_embeddings").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# |                                                                                                text|sentiment|                                                                                            document|                                                                                           sentences|                                                                                               token|                                                                                               lemma|                                                                                          embeddings|                                                                                 sentence_embeddings|                                                                        prediction|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# |  pfizerbiontech tozinameran has reported adverse reactions and at least deaths under death category|      0.0|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{document, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at least deaths ...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{token, 0, 13, pfizerbiontech, {sentence -> 0}, []}, {token, 15, 25, tozinameran, {sentence -> 0...|[{word_embeddings, 0, 13, pfizerbiontech, {isOOV -> false, pieceId -> -1, isWordStart -> true, to...|[{sentence_embeddings, 0, 97, pfizerbiontech tozinameran has reported adverse reactions and at le...| [{category, 0, 97, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |mom is doing panic buying whereas dad panic selling dad coronavirusindia covaxin coronaviruspandemic|      0.0|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{document, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirusindia covax...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, is, {sentence -> 0}, []}, {token, 7, 11, ...|[{token, 0, 2, mom, {sentence -> 0}, []}, {token, 4, 5, be, {sentence -> 0}, []}, {token, 7, 11, ...|[{word_embeddings, 0, 2, mom, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> mom, ...|[{sentence_embeddings, 0, 99, mom is doing panic buying whereas dad panic selling dad coronavirus...| [{category, 0, 99, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |today is my birthday for my gift my sons mother and i were able to get our first dose moderna vac...|      1.0|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{document, 0, 146, today is my birthday for my gift my sons mother and i were able to get our fi...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, is, {sentence -> 0}, []}, {token, 9, 10...|[{token, 0, 4, today, {sentence -> 0}, []}, {token, 6, 7, be, {sentence -> 0}, []}, {token, 9, 10...|[{word_embeddings, 0, 4, today, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> tod...|[{sentence_embeddings, 0, 146, today is my birthday for my gift my sons mother and i were able to...|[{category, 0, 146, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                            omi hospital karachi is charging rs for sputnikv vaccine|      1.0|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|  [{document, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence -> 0}, []}]|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{token, 0, 2, omi, {sentence -> 0}, []}, {token, 4, 11, hospital, {sentence -> 0}, []}, {token, ...|[{word_embeddings, 0, 2, omi, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> omi, ...|[{sentence_embeddings, 0, 55, omi hospital karachi is charging rs for sputnikv vaccine, {sentence...| [{category, 0, 55, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |our beloved pm shri narendra modi takes his st covid shot covaxin today ok hand syringe covaxin c...|      2.0|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{document, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin today ok ha...|[{token, 0, 2, our, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 1...|[{token, 0, 2, we, {sentence -> 0}, []}, {token, 4, 10, beloved, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 2, we, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> we, se...|[{sentence_embeddings, 0, 117, our beloved pm shri narendra modi takes his st covid shot covaxin ...|[{category, 0, 117, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |     super happy to get the moderna vaccine syringe no side effects whatsoever dose trophy thank you|      2.0|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{document, 0, 94, super happy to get the moderna vaccine syringe no side effects whatsoever dose...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, super, {sentence -> 0}, []}, {token, 6, 10, happy, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, super, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> sup...|[{sentence_embeddings, 0, 94, super happy to get the moderna vaccine syringe no side effects what...| [{category, 0, 94, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                covaxin s phase trials results likely next month read more covid india covid vaccine|      1.0|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{document, 0, 83, covaxin s phase trials results likely next month read more covid india covid v...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{token, 0, 6, covaxin, {sentence -> 0}, []}, {token, 8, 8, s, {sentence -> 0}, []}, {token, 10, ...|[{word_embeddings, 0, 6, covaxin, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> c...|[{sentence_embeddings, 0, 83, covaxin s phase trials results likely next month read more covid in...| [{category, 0, 83, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                          dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand|      1.0|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{document, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur complex kand, {s...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{token, 0, 3, dose, {sentence -> 0}, []}, {token, 5, 6, at, {sentence -> 0}, []}, {token, 8, 16,...|[{word_embeddings, 0, 3, dose, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> dose...|[{sentence_embeddings, 0, 73, dose at terapanth bhavan ward covaxin terapanth bhavan thakur compl...| [{category, 0, 73, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                    we call on usg to act with speed to trf vaccine tech for global scale up moderna|      1.0|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{document, 0, 79, we call on usg to act with speed to trf vaccine tech for global scale up moder...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{token, 0, 1, we, {sentence -> 0}, []}, {token, 3, 6, call, {sentence -> 0}, []}, {token, 8, 9, ...|[{word_embeddings, 0, 1, we, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> we, se...|[{sentence_embeddings, 0, 79, we call on usg to act with speed to trf vaccine tech for global sca...| [{category, 0, 79, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |    full vaccinated with moderna first shot no sides second arm a bit sore at injection site tired r|      0.0|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{document, 0, 95, full vaccinated with moderna first shot no sides second arm a bit sore at inje...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinated, {sentence -> 0}, []}, {toke...|[{token, 0, 3, full, {sentence -> 0}, []}, {token, 5, 14, vaccinate, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 3, full, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> full...|[{sentence_embeddings, 0, 95, full vaccinated with moderna first shot no sides second arm a bit s...| [{category, 0, 95, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                     this laughing at how perfect this tweet is moderna modernablock|      1.0|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{document, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {sentence -> ...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laughing, {sentence -> 0}, []}, {token,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 12, laugh, {sentence -> 0}, []}, {token, 14...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> this...|[{sentence_embeddings, 0, 62, this laughing at how perfect this tweet is moderna modernablock, {s...| [{category, 0, 62, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                   i got vaccinated sinovac stdose frontliner nurse covidvaccination|      1.0|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{document, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, {sentence -...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, got, {sentence -> 0}, []}, {token, 6, 15, v...|[{token, 0, 0, i, {sentence -> 0}, []}, {token, 2, 4, get, {sentence -> 0}, []}, {token, 6, 15, v...|[{word_embeddings, 0, 0, i, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> i, sent...|[{sentence_embeddings, 0, 64, i got vaccinated sinovac stdose frontliner nurse covidvaccination, ...| [{category, 0, 64, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                                                age d d slots covaxin on gvg invivo hospital rs bbmp|      1.0|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|      [{document, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> 0}, []}]|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{token, 0, 2, age, {sentence -> 0}, []}, {token, 4, 4, d, {sentence -> 0}, []}, {token, 6, 6, d,...|[{word_embeddings, 0, 2, age, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> age, ...|[{sentence_embeddings, 0, 51, age d d slots covaxin on gvg invivo hospital rs bbmp, {sentence -> ...| [{category, 0, 51, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |                     this is bad news the first shot was bad enough my arm hurt for ten days moderna|      0.0|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{document, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten days modern...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, is, {sentence -> 0}, []}, {token, 8, 10,...|[{token, 0, 3, this, {sentence -> 0}, []}, {token, 5, 6, be, {sentence -> 0}, []}, {token, 8, 10,...|[{word_embeddings, 0, 3, this, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> this...|[{sentence_embeddings, 0, 78, this is bad news the first shot was bad enough my arm hurt for ten ...| [{category, 0, 78, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |yep just guess who has bribed our governments more pfizer moderna astrazeneca it s all a sham no ...|      0.0|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{document, 0, 242, yep just guess who has bribed our governments more pfizer moderna astrazeneca...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{token, 0, 2, yep, {sentence -> 0}, []}, {token, 4, 7, just, {sentence -> 0}, []}, {token, 9, 13...|[{word_embeddings, 0, 2, yep, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> yep, ...|[{sentence_embeddings, 0, 242, yep just guess who has bribed our governments more pfizer moderna ...|[{category, 0, 242, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |with approval to rd vaccine sputnikv amp its roll out expected in a few weeks india s vaccination...|      1.0|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{document, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in a few weeks...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{token, 0, 3, with, {sentence -> 0}, []}, {token, 5, 12, approval, {sentence -> 0}, []}, {token,...|[{word_embeddings, 0, 3, with, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> with...|[{sentence_embeddings, 0, 241, with approval to rd vaccine sputnikv amp its roll out expected in ...|[{category, 0, 241, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |delhi prime minister narendramodi takes his second dose of covid vaccine at aiims he received the...|      1.0|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{document, 0, 193, delhi prime minister narendramodi takes his second dose of covid vaccine at a...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, delhi, {sentence -> 0}, []}, {token, 6, 10, prime, {sentence -> 0}, []}, {token, 1...|[{word_embeddings, 0, 4, delhi, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> del...|[{sentence_embeddings, 0, 193, delhi prime minister narendramodi takes his second dose of covid v...|[{category, 0, 193, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |china airplane chad chad is the latest african country that receives china donated sinopharm covi...|      1.0|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{document, 0, 122, china airplane chad chad is the latest african country that receives china do...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{token, 0, 4, china, {sentence -> 0}, []}, {token, 6, 13, airplane, {sentence -> 0}, []}, {token...|[{word_embeddings, 0, 4, china, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> chi...|[{sentence_embeddings, 0, 122, china airplane chad chad is the latest african country that receiv...|[{category, 0, 122, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |group rolls out covid vaccination programme via vaccination covidvaccine frontlineworkers frontli...|      2.0|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{document, 0, 136, group rolls out covid vaccination programme via vaccination covidvaccine fron...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, rolls, {sentence -> 0}, []}, {token, 1...|[{token, 0, 4, group, {sentence -> 0}, []}, {token, 6, 10, roll, {sentence -> 0}, []}, {token, 12...|[{word_embeddings, 0, 4, group, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> gro...|[{sentence_embeddings, 0, 136, group rolls out covid vaccination programme via vaccination covidv...|[{category, 0, 136, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# |  russia s sputnikv vaccine to be produced by malaysia covid technologysharing gamaleya vaccinedeals|      1.0|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{document, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technologysharing g...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{token, 0, 5, russia, {sentence -> 0}, []}, {token, 7, 7, s, {sentence -> 0}, []}, {token, 9, 16...|[{word_embeddings, 0, 5, russia, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> ru...|[{sentence_embeddings, 0, 97, russia s sputnikv vaccine to be produced by malaysia covid technolo...| [{category, 0, 97, 1.0, {sentence -> 0, 1.0 -> 1.0, 0.0 -> 0.0, 2.0 -> 0.0}, []}]|
# +----------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- prediction: double (nullable = true)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00       170
#      Neutral       0.48      1.00      0.65       480
#     Positive       0.00      0.00      0.00       350
#
#     accuracy                           0.48      1000
#    macro avg       0.16      0.33      0.22      1000
# weighted avg       0.23      0.48      0.31      1000
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# - epoch = 5, batchsize = 64, lr = 0.005: 0.16, 0.33, 0.22
# - epoch = 10, batchsize = 64, lr = 0.005: 0.16, 0.33, 0.22
# - epoch = 10, batchsize = 32, lr = 0.005: 0.16, 0.33, 0.22

# %% [markdown]
# # **BERT labse and ClassifierDLApproach (✔️)**
# https://nlp.johnsnowlabs.com/2020/09/23/labse.html

# %%
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

embeddings = BertSentenceEmbeddings.pretrained("labse", "xx") \
            .setInputCols(["document"]) \
            .setOutputCol("sentence_embeddings")

classifierdl = ClassifierDLApproach().setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction") \
              .setLabelColumn("sentiment") \
              .setBatchSize(64) \
              .setMaxEpochs(1) \
              .setLr(0.005) \
              .setEnableOutputLogs(True)
# Out:
# labse download started this may take some time.
# Approximate size to download 1.7 GB
# [OK!]

# %%
nlp_pipeline_BERT = Pipeline(stages=[document, 
                                     embeddings, 
                                     classifierdl])

# %%
model_BERT_labse = nlp_pipeline_BERT.fit(train)

predict_test = model_BERT_labse.transform(test)

# %%
predict_test.show()

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.85      0.62      0.72       170
#      Neutral       0.76      0.79      0.77       480
#     Positive       0.73      0.78      0.75       350
#
#     accuracy                           0.76      1000
#    macro avg       0.78      0.73      0.75      1000
# weighted avg       0.76      0.76      0.76      1000

# %% [markdown]
# # **Save & Load model**

# %%
# SAVED MODEL
model_BERT_labse.stages[-1].write().overwrite().save('/content/drive/MyDrive/labse/bert_labse_model')

# %%
# LOAD MODEL
document = DocumentAssembler() \
          .setInputCol("text") \
          .setOutputCol("document")

embeddings = BertSentenceEmbeddings.pretrained("labse", "xx") \
      .setInputCols(["document"]) \
      .setOutputCol("sentence_embeddings")

classifierdl = ClassifierDLModel().load("/content/drive/MyDrive/labse/bert_labse_model") \
              .setInputCols(["sentence_embeddings"]) \
              .setOutputCol("prediction")
# Out:
# labse download started this may take some time.
# Approximate size to download 1.7 GB
# [OK!]

# %%
nlp_pipeline_BERT = Pipeline(stages=[document, 
                                     embeddings, 
                                     classifierdl])

# %%
model_BERT_labse = nlp_pipeline_BERT.fit(test)

predict_test = model_BERT_labse.transform(test)

# %%
predict_test.show()
# Out:
# +--------------------+---------+--------------------+--------------------+--------------------+
# |                text|sentiment|            document| sentence_embeddings|          prediction|
# +--------------------+---------+--------------------+--------------------+--------------------+
# |pfizerbiontech to...|      0.0|[[document, 0, 97...|[[sentence_embedd...|[[category, 0, 97...|
# |mom is doing pani...|      0.0|[[document, 0, 99...|[[sentence_embedd...|[[category, 0, 99...|
# |today is my birth...|      1.0|[[document, 0, 14...|[[sentence_embedd...|[[category, 0, 14...|
# |omi hospital kara...|      1.0|[[document, 0, 55...|[[sentence_embedd...|[[category, 0, 55...|
# |our beloved pm sh...|      2.0|[[document, 0, 11...|[[sentence_embedd...|[[category, 0, 11...|
# |super happy to ge...|      2.0|[[document, 0, 94...|[[sentence_embedd...|[[category, 0, 94...|
# |covaxin s phase t...|      1.0|[[document, 0, 83...|[[sentence_embedd...|[[category, 0, 83...|
# |dose at terapanth...|      1.0|[[document, 0, 73...|[[sentence_embedd...|[[category, 0, 73...|
# |we call on usg to...|      1.0|[[document, 0, 79...|[[sentence_embedd...|[[category, 0, 79...|
# |full vaccinated w...|      0.0|[[document, 0, 95...|[[sentence_embedd...|[[category, 0, 95...|
# |this laughing at ...|      1.0|[[document, 0, 62...|[[sentence_embedd...|[[category, 0, 62...|
# |i got vaccinated ...|      1.0|[[document, 0, 64...|[[sentence_embedd...|[[category, 0, 64...|
# |age d d slots cov...|      1.0|[[document, 0, 51...|[[sentence_embedd...|[[category, 0, 51...|
# |this is bad news ...|      0.0|[[document, 0, 78...|[[sentence_embedd...|[[category, 0, 78...|
# |yep just guess wh...|      0.0|[[document, 0, 24...|[[sentence_embedd...|[[category, 0, 24...|
# |with approval to ...|      1.0|[[document, 0, 24...|[[sentence_embedd...|[[category, 0, 24...|
# |delhi prime minis...|      1.0|[[document, 0, 19...|[[sentence_embedd...|[[category, 0, 19...|
# |china airplane ch...|      1.0|[[document, 0, 12...|[[sentence_embedd...|[[category, 0, 12...|
# |group rolls out c...|      2.0|[[document, 0, 13...|[[sentence_embedd...|[[category, 0, 13...|
# |russia s sputnikv...|      1.0|[[document, 0, 97...|[[sentence_embedd...|[[category, 0, 97...|
# +--------------------+---------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
predict_test = predict_test.select('text','sentiment','prediction.result').withColumn('prediction',f.col('result').getItem(0))
predict_test = predict_test.withColumn('prediction',f.col('prediction').cast("double"))
predict_test.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- sentiment: float (nullable = true)
#  |-- result: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- prediction: double (nullable = true)

# %%
pred_test_rp = predict_test.select('sentiment','prediction').toPandas()
print (classification_report(pred_test_rp['sentiment'], pred_test_rp['prediction'], target_names=['Negative','Neutral','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.85      0.62      0.72       170
#      Neutral       0.76      0.79      0.77       480
#     Positive       0.73      0.78      0.75       350
#
#     accuracy                           0.76      1000
#    macro avg       0.78      0.73      0.75      1000
# weighted avg       0.76      0.76      0.76      1000
